# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime
import pytz
import scipy.stats


import warnings

# Suppress the specific warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Team Data, including standings

# %%
teamURL = 'https://statsapi.web.nhl.com/api/v1/teams'

teams = requests.get(teamURL).json()
teams = teams['teams']

team_names = pd.DataFrame()

for team in teams:
    abbreviation = team['abbreviation']
    name = team['name']
    id = team['id']

    temp = pd.DataFrame({'abbreviation': [abbreviation], 'name': [name], 'id': [id]})

    team_names = pd.concat([team_names, temp], ignore_index=True)
    
# ----------------------------------------------------------------------#    
    
teamURL = 'https://statsapi.web.nhl.com/api/v1/teams/'
appendix = '/stats'

team_stats = pd.DataFrame()

for index, row in team_names.iterrows():

  fetchURL = teamURL + str(row['id']) + appendix

  # print(fetchURL)

  team = requests.get(fetchURL).json()
  stats = team['stats'][0]['splits'][0]['stat']
  name = team['stats'][0]['splits'][0]['team']['name']

  temp = pd.DataFrame([stats])
  temp['name'] = name

  team_stats = pd.concat([team_stats, temp], ignore_index=True)


team_stats = pd.merge(team_stats, team_names, on='name')
team_stats.set_index('name', inplace=True)

# %% [markdown]
# # Web Scrape Sked Data

# %% [markdown]
# ### Set Date for one before and one after window

# %%
baseURL = 'https://statsapi.web.nhl.com/api/v1/schedule'

# Date of lookahead
start = '?startDate=2023-11-02'

end = '&endDate=2023-11-06'

skedURL = baseURL + start + end

sked = requests.get(skedURL).json()

# %%
days = sked['dates']

eastern = pytz.timezone('US/Eastern')

# %%
# See teams with most games

teams_data = {}
games_data = []

for day in days[1:4]:
# for day in days:
    games = day['games']

    for game in games:
        home_team = game['teams']['home']['team']['name']
        away_team = game['teams']['away']['team']['name']

        if home_team not in teams_data:
            teams_data[home_team] = {'played': 0, 'home': 0, 'away': 0}
        if away_team not in teams_data:
            teams_data[away_team] = {'played': 0, 'home': 0, 'away': 0}

        teams_data[home_team]['played'] += 1
        teams_data[away_team]['played'] += 1
        teams_data[home_team]['home'] += 1
        teams_data[away_team]['away'] += 1

        games_data.append(game['gamePk'])

# Create a DataFrame
teams_df = pd.DataFrame.from_dict(teams_data, orient='index')
teams_df = teams_df.sort_values(by=['played', 'home'], ascending=False)

teams_df
# Out:
#                        played  home  away
# St. Louis Blues             2     2     0
# Chicago Blackhawks          2     2     0
# Buffalo Sabres              2     1     1
# Philadelphia Flyers         2     1     1
# Vegas Golden Knights        2     1     1
# New Jersey Devils           2     0     2
# Edmonton Oilers             1     1     0
# Arizona Coyotes             1     1     0
# Detroit Red Wings           1     1     0
# Ottawa Senators             1     1     0
# Toronto Maple Leafs         1     1     0
# Washington Capitals         1     1     0
# New York Islanders          1     1     0
# Minnesota Wild              1     1     0
# Seattle Kraken              1     1     0
# San Jose Sharks             1     1     0
# Vancouver Canucks           1     1     0
# Anaheim Ducks               1     1     0
# Nashville Predators         1     0     1
# Winnipeg Jets               1     0     1
# Montréal Canadiens          1     0     1
# Boston Bruins               1     0     1
# Tampa Bay Lightning         1     0     1
# Columbus Blue Jackets       1     0     1
# Los Angeles Kings           1     0     1
# Carolina Hurricanes         1     0     1
# Florida Panthers            1     0     1
# New York Rangers            1     0     1
# Calgary Flames              1     0     1
# Pittsburgh Penguins         1     0     1
# Dallas Stars                1     0     1
# Colorado Avalanche          1     0     1

# %% [markdown]
# # Scrape the Box Score data for season to-date

# %%
baseURL = 'https://statsapi.web.nhl.com/api/v1/game/'
appendix = '/feed/live'

year = '202302'
game = 1
range_end = int(str(games_data[0]-1)[-4:])

date_format_game = "%d-%m-%Y"
date_format = "%d-%m-%Y"
date_format_birth = "%Y-%m-%d"

awaylogs = {}
homelogs = {}

# Subtract games not done on Sunday!
for i in range(range_end):
    
    gameURL = baseURL + year + str(i+1).zfill(4) + appendix
    
    print(gameURL)

    game = requests.get(gameURL).json()
    
    away = game['liveData']['boxscore']['teams']['away']['players']
    awayname = game['gameData']['teams']['away']['abbreviation']
    home = game['liveData']['boxscore']['teams']['home']['players']
    homename = game['gameData']['teams']['home']['abbreviation']
    birthday = game['gameData']['players']

    if game['liveData']['linescore']['currentPeriod'] > 3:
        OT = True
    else:
        OT = False

    awayteam = []

    date = game['gameData']['datetime']['dateTime']

    datetime_obj = datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ')

    utc_timestamp = pytz.utc.localize(datetime_obj)
    eastern_timezone = pytz.timezone('US/Eastern')
    eastern_time = utc_timestamp.astimezone(eastern_timezone)

    formatted_date_string = eastern_time.strftime('%d-%m-%Y')
    game_date = datetime.strptime(formatted_date_string, date_format)

    for player in away:
        awayteam.append(player)

    for player in awayteam:
        name = away[player]['person']['fullName']
        try:
            birth_date = birthday[player]['birthDate']
            birthday_date = datetime.strptime(birth_date, date_format_birth)
            days_aged = game_date - birthday_date
        except:
            birth_date = '1900-01-01'
        stats = away[player]['stats']
        try: 
            if list(stats.keys())[0] == 'skaterStats':
                position = away[player]['position']['abbreviation']
                stats = stats['skaterStats']
    #             stats['name'] = name
                stats['position'] = position
                stats['timeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['timeOnIce'].split(':'))))
                stats['evenTimeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['evenTimeOnIce'].split(':'))))
                stats['powerPlayTimeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['powerPlayTimeOnIce'].split(':'))))
                stats['shortHandedTimeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['shortHandedTimeOnIce'].split(':'))))
            if list(stats.keys())[0] == 'goalieStats':
                position = 'G'
                stats = stats['goalieStats']
    #             stats['name'] = name
                stats['position'] = position
                stats['timeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['timeOnIce'].split(':'))))
                if OT & (stats['decision'] == "L"):
                    stats['decision'] = 'OTL'
                shots_against = stats['shortHandedShotsAgainst'] + stats['evenShotsAgainst'] + stats['powerPlayShotsAgainst']
                if (stats['saves'] == shots_against) & ((stats['decision'] == "W") | (stats['decision'] == "OTL")):
                    stats['shutout'] = '1'
                else:
                    stats['shutout'] = '0'
        except:
            position = away[player]['position']['abbreviation']
            stats['name'] = name

        awaylogs[player  + '-' + formatted_date_string] = stats
        awaylogs[player  + '-' + formatted_date_string]['position'] = position
        awaylogs[player  + '-' + formatted_date_string]['date'] = formatted_date_string
        awaylogs[player  + '-' + formatted_date_string]['name'] = name
        awaylogs[player  + '-' + formatted_date_string]['team'] = awayname
        awaylogs[player  + '-' + formatted_date_string]['opponent'] = homename
        awaylogs[player  + '-' + formatted_date_string]['birthdate'] = birth_date
        awaylogs[player  + '-' + formatted_date_string]['id'] = player
        awaylogs[player  + '-' + formatted_date_string]['aged'] = days_aged.days


    hometeam = []

    # date = game['gameData']['datetime']['dateTime']

    for player in home:
        hometeam.append(player)

    for player in hometeam:
        name = home[player]['person']['fullName']
        try:
            birth_date = birthday[player]['birthDate']
            birthday_date = datetime.strptime(birth_date, date_format_birth)
            days_aged = game_date - birthday_date
        except:
            birth_date = '1900-01-01'
        stats = home[player]['stats']
        try: 
            if list(stats.keys())[0] == 'skaterStats':
                position = home[player]['position']['abbreviation']
                stats = stats['skaterStats']
    #             stats['name'] = name
                stats['position'] = position
                stats['timeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['timeOnIce'].split(':'))))
                stats['evenTimeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['evenTimeOnIce'].split(':'))))
                stats['powerPlayTimeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['powerPlayTimeOnIce'].split(':'))))
                stats['shortHandedTimeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['shortHandedTimeOnIce'].split(':'))))
            if list(stats.keys())[0] == 'goalieStats':
                position = 'G'
                stats = stats['goalieStats']
    #             stats['name'] = name
                stats['position'] = position
                stats['timeOnIce'] = sum(int(x) * 60**i for i, x in enumerate(reversed(stats['timeOnIce'].split(':'))))
                if OT & (stats['decision'] == "L"):
                    stats['decision'] = 'OTL'
                shots_against = stats['shortHandedShotsAgainst'] + stats['evenShotsAgainst'] + stats['powerPlayShotsAgainst']
                if (stats['saves'] == shots_against) & ((stats['decision'] == "W") | (stats['decision'] == "OTL")):
                    stats['shutout'] = '1'
                else:
                    stats['shutout'] = '0'
        except:
            position = home[player]['position']['abbreviation']
            stats['name'] = name
            
                

        homelogs[player  + '-' + formatted_date_string] = stats
        homelogs[player  + '-' + formatted_date_string]['position'] = position
        homelogs[player  + '-' + formatted_date_string]['date'] = formatted_date_string
        homelogs[player  + '-' + formatted_date_string]['name'] = name
        homelogs[player  + '-' + formatted_date_string]['team'] = homename
        homelogs[player  + '-' + formatted_date_string]['opponent'] = awayname
        homelogs[player  + '-' + formatted_date_string]['birthdate'] = birth_date
        homelogs[player  + '-' + formatted_date_string]['id'] = player
        homelogs[player  + '-' + formatted_date_string]['aged'] = days_aged.days
# Out:
# https://statsapi.web.nhl.com/api/v1/game/2023020001/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020002/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020003/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020004/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020005/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020006/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020007/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020008/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020009/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020010/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020011/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020012/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020013/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020014/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020015/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020016/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020017/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020018/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020019/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020020/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020021/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020022/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020023/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020024/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020025/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020026/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020027/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020028/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020029/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020030/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020031/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020032/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020033/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020034/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020035/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020036/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020037/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020038/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020039/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020040/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020041/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020042/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020043/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020044/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020045/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020046/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020047/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020048/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020049/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020050/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020051/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020052/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020053/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020054/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020055/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020056/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020057/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020058/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020059/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020060/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020061/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020062/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020063/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020064/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020065/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020066/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020067/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020068/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020069/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020070/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020071/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020072/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020073/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020074/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020075/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020076/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020077/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020078/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020079/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020080/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020081/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020082/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020083/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020084/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020085/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020086/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020087/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020088/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020089/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020090/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020091/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020092/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020093/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020094/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020095/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020096/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020097/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020098/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020099/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020100/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020101/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020102/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020103/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020104/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020105/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020106/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020107/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020108/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020109/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020110/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020111/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020112/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020113/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020114/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020115/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020116/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020117/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020118/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020119/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020120/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020121/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020122/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020123/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020124/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020125/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020126/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020127/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020128/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020129/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020130/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020131/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020132/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020133/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020134/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020135/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020136/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020137/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020138/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020139/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020140/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020141/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020142/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020143/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020144/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020145/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020146/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020147/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020148/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020149/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020150/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020151/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020152/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020153/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020154/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020155/feed/live
# https://statsapi.web.nhl.com/api/v1/game/2023020156/feed/live

# %%
home_df = pd.DataFrame(homelogs)
home_df = home_df.transpose()

away_df = pd.DataFrame(awaylogs)
away_df = away_df.transpose()

columns_to_convert1 = ['timeOnIce', 'assists', 'goals', 'shots', 'hits', 'powerPlayGoals', 'powerPlayAssists', 'penaltyMinutes']
columns_to_convert2 = ['faceOffWins', 'faceoffTaken', 'takeaways', 'giveaways', 'shortHandedGoals', 'shortHandedAssists']
columns_to_convert3 = ['blocked', 'plusMinus', 'evenTimeOnIce', 'powerPlayTimeOnIce', 'shortHandedTimeOnIce', 'pim', 'shutout']
columns_to_convert4 = ['saves', 'powerPlaySaves', 'shortHandedSaves', 'evenSaves', 'shortHandedShotsAgainst', 'evenShotsAgainst', 'powerPlayShotsAgainst']

home_df[columns_to_convert1] = home_df[columns_to_convert1].fillna(0).astype(int)
home_df[columns_to_convert2] = home_df[columns_to_convert2].fillna(0).astype(int)
home_df[columns_to_convert3] = home_df[columns_to_convert3].fillna(0).astype(int)
home_df[columns_to_convert4] = home_df[columns_to_convert4].fillna(0).astype(int)

away_df[columns_to_convert1] = away_df[columns_to_convert1].fillna(0).astype(int)
away_df[columns_to_convert2] = away_df[columns_to_convert2].fillna(0).astype(int)
away_df[columns_to_convert3] = away_df[columns_to_convert3].fillna(0).astype(int)
away_df[columns_to_convert4] = away_df[columns_to_convert4].fillna(0).astype(int)

all_df = pd.concat([home_df, away_df], axis=0)

all_df['date'] = pd.to_datetime(all_df['date'], format='%d-%m-%Y')
all_df['birthdate'] = pd.to_datetime(all_df['birthdate'], format='%Y-%m-%d')
all_df = all_df.sort_values(by='date')

# %%
# 22-23 FANTASYPOINTS
for index, row in all_df.iterrows():
    d = 0
    so = 0
    w = 0

    if row['timeOnIce'] > 0:
        all_df.at[index, 'gamePlayed'] = 1


    if row['position'] == "G":
        if (row['shutout'] == 1) & (row['timeOnIce'] < 3446):
            all_df.at[index, 'shutout'] = 0
        if row['shutout'] == 1:
            so = 3
        else:
            so = 0
        if row['decision'] == "W":
            d = 4
            w += 1
        elif row['decision'] == "OTL":
            d = 1
        elif row['decision'] == "":
            d = 0
        else:
            d = 0
        shots_against = row['shortHandedShotsAgainst'] + row['evenShotsAgainst'] + row['powerPlayShotsAgainst']
        all_df.at[index, 'shots_against'] = shots_against
        ga = (shots_against - row['saves']) * -2
        all_df.at[index, 'goals_against'] = abs(ga)/2
        saves = row['saves'] * .2
        fp = d + so + ga + saves
        all_df.at[index, 'fantasyPoints'] = fp
        all_df.at[index, 'decisionPoints'] = d
        all_df.at[index, 'wins'] = w

    else:
        st = row['powerPlayGoals'] + row['powerPlayAssists'] + row['shortHandedGoals'] + row['shortHandedAssists']
        fp = (row['goals']*2) + row['assists'] + (st * .5) + (row['blocked'] * .5) + ((row['hits'] + row['shots']) * .1)
        all_df.at[index, 'fantasyPoints'] = fp
        all_df.at[index, 'specialTeams'] = st

# %%
# Remove all zero ice time games

all_df = all_df[all_df['timeOnIce'] != 0]

# %%
# Replace Sebastian Aho, D, with Sebastian Aho (D)

all_df.loc[(all_df['name'] == 'Sebastian Aho') & (all_df['position'] == 'D')] = all_df.loc[(all_df['name'] == 'Sebastian Aho') & (all_df['position'] == 'D')].replace('Sebastian Aho', 'Sebastian Aho (D)')

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5943 entries, ID8478519-10-10-2023 to ID8481535-02-11-2023
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   timeOnIce                   5943 non-null   int32
#  1   assists                     5943 non-null   int32
#  2   goals                       5943 non-null   int32
#  3   shots                       5943 non-null   int32
#  4   hits                        5943 non-null   int32
#  5   powerPlayGoals              5943 non-null   int32
#  6   powerPlayAssists            5943 non-null   int32
#  7   penaltyMinutes              5943 non-null   int32
#  8   faceOffPct                  2179 non-null   object
#  9   faceOffWins                 5943 non-null   int32
#  10  faceoffTaken                5943 non-null   int32
#  11  takeaways                   5943 non-null   int32
#  12  giveaways                   5943 non-null   int32
#  13  shortHandedGoals            5943 non-null   int32
#  14  shortHandedAssists          5943 non-null   int32
#  15  blocked                     5943 non-null   int32
#  16  plusMinus                   5943 non-null   int32
#  17  evenTimeOnIce               5943 non-null   int32
#  18  powerPlayTimeOnIce          5943 non-null   int32
#  19  shortHandedTimeOnIce        5943 non-null   int32
#  20  position                    5943 non-null   object
#  21  date                        5943 non-null   datetime64[ns]
#  22  name                        5943 non-null   object
#  23  team                        5943 non-null   object
#  24  opponent                    5943 non-null   object
#  25  birthdate                   5943 non-null   datetime64[ns]
#  26  id                          5943 non-null   object
#  27  aged                        5943 non-null   object
#  28  pim                         5943 non-null   int32
#  29  saves                       5943 non-null   int32
#  30  powerPlaySaves              5943 non-null   int32
#  31  shortHandedSaves            5943 non-null   int32
#  32  evenSaves                   5943 non-null   int32
#  33  shortHandedShotsAgainst     5943 non-null   int32
#  34  evenShotsAgainst            5943 non-null   int32
#  35  powerPlayShotsAgainst       5943 non-null   int32
#  36  decision                    332 non-null    object
#  37  savePercentage              332 non-null    object
#  38  powerPlaySavePercentage     313 non-null    object
#  39  shortHandedSavePercentage   174 non-null    object
#  40  evenStrengthSavePercentage  332 non-null    object
#  41  shutout                     5943 non-null   int32
#  42  gamePlayed                  5943 non-null   float64
#  43  fantasyPoints               5943 non-null   float64
#  44  specialTeams                5611 non-null   float64
#  45  shots_against               332 non-null    float64
#  46  goals_against               332 non-null    float64
#  47  decisionPoints              332 non-null    float64
#  48  wins                        332 non-null    float64
# dtypes: datetime64[ns](2), float64(7), int32(28), object(12)
# memory usage: 1.6+ MB

# %% [markdown]
# # Build Summary Stats Season to Date

# %%
# Build summary stats for rankings

def first_non_na_position(x):
    non_na_values = x[x != 'N/A']
    return non_na_values.iloc[0] if not non_na_values.empty else 'N/A'

summary_stats = all_df.groupby('id').agg({
    'name': 'first',
    'team': 'first',
    'position': first_non_na_position,
    'timeOnIce': 'sum',
    'gamePlayed': 'sum',
    'goals': 'sum',
    'assists': 'sum',
    'specialTeams': 'sum',
    'shots': 'sum',
    'hits': 'sum',
    'blocked': 'sum',
    'evenTimeOnIce': 'sum',
    'powerPlayTimeOnIce': 'sum',
    'shortHandedTimeOnIce': 'sum',
    'saves': 'sum',
    'powerPlaySaves': 'sum',
    'shortHandedSaves': 'sum',
    'evenSaves': 'sum',
    'shortHandedShotsAgainst': 'sum',
    'evenShotsAgainst': 'sum',
    'powerPlayShotsAgainst': 'sum',
    'decisionPoints': 'sum',
    'wins': 'sum',
    # 'decision': 'sum',
    'shutout': 'sum',
    'fantasyPoints': 'sum'
}).reset_index()


# summary_stats = summary_stats.rename(columns={'date': 'gp'})
# summary_stats['gp'] = summary_stats['gp'].apply(lambda x: len(x))
summary_stats['gamePlayed'] = summary_stats['gamePlayed'].astype(int)
summary_stats['decisionPoints'] = summary_stats['decisionPoints'].astype(int)
summary_stats['wins'] = summary_stats['wins'].astype(int)
summary_stats['specialTeams'] = summary_stats['specialTeams'].astype(int)


summary_stats['FPP60'] = (summary_stats['fantasyPoints'] / summary_stats['timeOnIce'] * 3600).round(2)
summary_stats['FPPG'] = (summary_stats['fantasyPoints'] / summary_stats['gamePlayed']).round(2)

summary_stats = summary_stats.sort_values(by='FPPG', ascending=False)
# pd.set_option('display.max_rows', None)
summary_stats.set_index('name', inplace=True)

player_list = summary_stats.index.to_list()

summary_stats.head()
# Out:
#                         id team position  timeOnIce  gamePlayed  goals  \
# name
# Semyon Varlamov  ID8473575  NYI        G      10747           3      0
# Jeremy Swayman   ID8480280  BOS        G      18230           5      0
# Anthony Stolarz  ID8476932  FLA        G       3569           1      0
# Jonathan Quick   ID8471734  NYR        G       8752           3      0
# Jake Oettinger   ID8479979  DAL        G      22174           6      0
#
#                  assists  specialTeams  shots  hits  ...  evenSaves  \
# name                                                 ...
# Semyon Varlamov        0             0    108     0  ...         85
# Jeremy Swayman         0             0    152     0  ...        108
# Anthony Stolarz        0             0     28     0  ...         23
# Jonathan Quick         0             0     57     0  ...         54
# Jake Oettinger         0             0    198     0  ...        145
#
#                  shortHandedShotsAgainst  evenShotsAgainst  \
# name
# Semyon Varlamov                        4                88
# Jeremy Swayman                         8               114
# Anthony Stolarz                        2                23
# Jonathan Quick                         1                55
# Jake Oettinger                         5               156
#
#                  powerPlayShotsAgainst  decisionPoints  wins  shutout  \
# name
# Semyon Varlamov                     16               8     2        2
# Jeremy Swayman                      30              20     5        1
# Anthony Stolarz                      3               4     1        0
# Jonathan Quick                       1               8     2        1
# Jake Oettinger                      37              21     5        0
#
#                  fantasyPoints  FPP60  FPPG
# name
# Semyon Varlamov           29.0   9.71  9.67
# Jeremy Swayman            38.0   7.50  7.60
# Anthony Stolarz            7.4   7.46  7.40
# Jonathan Quick            20.2   8.31  6.73
# Jake Oettinger            34.2   5.55  5.70
#
# [5 rows x 27 columns]

# %%
skaters_summary = summary_stats.loc[summary_stats['position'] != "G"]
skaters_summary = skaters_summary.drop(columns=['saves', 'powerPlaySaves',	'shortHandedSaves',	'evenSaves',	'shortHandedShotsAgainst',	'evenShotsAgainst',	'powerPlayShotsAgainst',	'decisionPoints',	'wins',	'shutout'])

goalies_summary = summary_stats.loc[summary_stats['position'] == "G"]
goalies_summary = goalies_summary.drop(columns=['goals',	'assists',	'specialTeams',	'hits',	'blocked',	'evenTimeOnIce',	'powerPlayTimeOnIce',	'shortHandedTimeOnIce'])

goalies = all_df.loc[all_df['position'] == 'G']

skaters = all_df.loc[all_df['position'] != 'G']
skaters['specialTeams'] = skaters['specialTeams'].astype(int)

# %% [markdown]
# # Pull in Rostership Data from ESPN

# %%
espnapi = 'https://lm-api-reads.fantasy.espn.com/apis/v3/games/fhl/seasons/2024/players?view=players_wl&filter=%7B%22filterActive%22%3A%7B%22value%22%3Atrue%7D%7D'

rosters = requests.get(espnapi).json()

# pprint(rosters[9])

rostership = pd.DataFrame()

for player in rosters:
    n = player['fullName']
    percent = player['ownership']['percentOwned']
    pos = player['eligibleSlots']
    dpos = player['defaultPositionId']
    if (n == 'Sebastian Aho') & (dpos == 4):
        n = 'Sebastian Aho (D)'
#     print(n)
    temp = pd.DataFrame({'name': [n], 'rostered': [percent]})
    rostership = pd.concat([rostership, temp], ignore_index=True)
    
rostership.head()
# Out:
#                name  rostered
# 0    Calle Jarnkrok  0.921484
# 1     Charlie Coyle  3.974375
# 2  Charlie Lindgren  0.196141
# 3    Mike Vecchione  0.022771
# 4       Olle Alsing  0.007591

# %% [markdown]
# ### Fix the accented players

# %%
fixes = {
    'Tim Stutzle': 'Tim Stützle',
    'Alex Barre-Boulet': 'Alex Barré-Boulet',
    'Jani Hakanpaa': 'Jani Hakanpää',
    'Jesse Ylonen': 'Jesse Ylönen',
    'Alexis Lafreniere': 'Alexis Lafrenière',
    'Gustav Lindstrom': 'Gustav Lindström',
    'Alexander Kerfoot': 'Alex Kerfoot',
    'Johnny Beecher': 'John Beecher',
    'Samuel Walker': 'Sammy Walker'
}

rostership['name'].replace(fixes, inplace=True)

# %%
#Merge

summary_stats = summary_stats.merge(rostership, on='name', how='left')

# %%
#Check for nulls
rows_with_null_rostered = summary_stats[summary_stats['rostered'].isna()]
rows_with_null_rostered

# summary_stats_with_percent.loc[rows_with_null_rostered.index, 'rostered'] = 0

# %%
summary_stats
# Out:
#                 name         id team position  timeOnIce  gamePlayed  goals  \
# 0    Semyon Varlamov  ID8473575  NYI        G      10747           3      0
# 1     Jeremy Swayman  ID8480280  BOS        G      18230           5      0
# 2    Anthony Stolarz  ID8476932  FLA        G       3569           1      0
# 3     Jonathan Quick  ID8471734  NYR        G       8752           3      0
# 4     Jake Oettinger  ID8479979  DAL        G      22174           6      0
# ..               ...        ...  ...      ...        ...         ...    ...
# 747       Dan Vladar  ID8478435  CGY        G       7191           2      0
# 748   Cayden Primeau  ID8480051  MTL        G       3468           1      0
# 749   Pheonix Copley  ID8477831  LAK        G       7957           3      0
# 750  Pyotr Kochetkov  ID8481611  CAR        G       9151           3      0
# 751    Samuel Ersson  ID8481035  PHI        G      10261           3      0
#
#      assists  specialTeams  shots  ...  shortHandedShotsAgainst  \
# 0          0             0    108  ...                        4
# 1          0             0    152  ...                        8
# 2          0             0     28  ...                        2
# 3          0             0     57  ...                        1
# 4          0             0    198  ...                        5
# ..       ...           ...    ...  ...                      ...
# 747        0             0     57  ...                        0
# 748        0             0     33  ...                        0
# 749        0             0     52  ...                        3
# 750        0             0     67  ...                        3
# 751        0             0     59  ...                        2
#
#      evenShotsAgainst  powerPlayShotsAgainst  decisionPoints  wins  shutout  \
# 0                  88                     16               8     2        2
# 1                 114                     30              20     5        1
# 2                  23                      3               4     1        0
# 3                  55                      1               8     2        1
# 4                 156                     37              21     5        0
# ..                ...                    ...             ...   ...      ...
# 747                40                     17               4     1        0
# 748                26                      7               0     0        0
# 749                40                      9               5     1        0
# 750                52                     12               0     0        0
# 751                52                      5               1     0        0
#
#      fantasyPoints  FPP60  FPPG   rostered
# 0             29.0   9.71  9.67   3.297906
# 1             38.0   7.50  7.60  91.198115
# 2              7.4   7.46  7.40   0.421171
# 3             20.2   8.31  6.73   7.526228
# 4             34.2   5.55  5.70  99.606162
# ..             ...    ...   ...        ...
# 747           -4.4  -2.20 -2.20   0.307164
# 748           -2.2  -2.28 -2.20   0.066901
# 749           -8.8  -3.98 -2.93   4.066116
# 750          -10.8  -4.25 -3.60  27.864191
# 751          -18.0  -6.32 -6.00   0.182457
#
# [752 rows x 29 columns]

# %% [markdown]
# # Check teams with back-to-backs

# %%
# See teams that play back-to-back

def check_consecutive_dates(game1, game2):
    date_format = '%Y-%m-%dT%H:%M:%SZ'
    date1 = datetime.strptime(game1['gameDate'], date_format)
    date2 = datetime.strptime(game2['gameDate'], date_format)
    return (date2 - date1).days == 1

teams_playing_consecutive_days = set()

for i in range(len(days)-1):
    current_day_games = days[i]['games']
    next_day_games = days[i+1]['games']

    teams_on_next_day = set()

    for game2 in next_day_games:
        home_team_2 = game2['teams']['home']['team']['name']
        away_team_2 = game2['teams']['away']['team']['name']
        teams_on_next_day.add(home_team_2)
        teams_on_next_day.add(away_team_2)

    for game1 in current_day_games:
        home_team_1 = game1['teams']['home']['team']['name']
        away_team_1 = game1['teams']['away']['team']['name']

        if (home_team_1 in teams_on_next_day) and check_consecutive_dates(game1, game2):
            teams_playing_consecutive_days.add(home_team_1)
        elif (away_team_1 in teams_on_next_day) and check_consecutive_dates(game1, game2):
            teams_playing_consecutive_days.add(away_team_1)

print("Teams playing on consecutive days:")
for team in teams_playing_consecutive_days:
    print(team)
# Out:
# Teams playing on consecutive days:
# New Jersey Devils
# St. Louis Blues
# Chicago Blackhawks
# Buffalo Sabres

# %% [markdown]
# # Check teams not playing

# %%
team_check = teams_df.index.to_list()

nhl_teams = [
    'New Jersey Devils', 'New York Islanders', 'New York Rangers',
    'Philadelphia Flyers', 'Pittsburgh Penguins', 'Boston Bruins',
    'Buffalo Sabres', 'Montréal Canadiens', 'Ottawa Senators',
    'Toronto Maple Leafs', 'Carolina Hurricanes', 'Florida Panthers',
    'Tampa Bay Lightning', 'Washington Capitals', 'Chicago Blackhawks',
    'Detroit Red Wings', 'Nashville Predators', 'St. Louis Blues',
    'Calgary Flames', 'Colorado Avalanche', 'Edmonton Oilers',
    'Vancouver Canucks', 'Anaheim Ducks', 'Dallas Stars',
    'Los Angeles Kings', 'San Jose Sharks', 'Columbus Blue Jackets',
    'Minnesota Wild', 'Winnipeg Jets', 'Arizona Coyotes',
    'Vegas Golden Knights', 'Seattle Kraken'
]

# # teams_df.index.values

for team in nhl_teams:

    if team not in team_check:
        print(team)

# %% [markdown]
# # Build opponent FPAPG

# %%
opponent_stats = skaters.groupby('opponent').agg({
    'timeOnIce': 'sum',
    'assists': 'sum',
    'goals': 'sum',
    'shots': 'sum',
    'hits': 'sum',
    'blocked': 'sum',
#     'fantasyPoints': ['sum', ('mean', lambda x: round(x.mean(), 2))],
    'fantasyPoints': 'sum',
    'date': 'nunique',
    'powerPlayGoals': 'sum',
    'powerPlayAssists': 'sum'
    # Add more columns as needed
})

opponent_stats['FPAPG'] = round(opponent_stats['fantasyPoints'] / opponent_stats['date'], 2)
opponent_stats['FPAPG_Rank'] = opponent_stats['FPAPG'].rank(ascending=False, method='min').astype(int)

# opponent_stats['BPG'] = round(opponent_stats['blocked'] / opponent_stats['date'], 2)
# opponent_stats['BPG_Rank'] = opponent_stats['BPG'].rank(ascending=True, method='min').astype(int)

opponent_stats = opponent_stats.rename_axis('abbreviation')

opponent_stats = pd.merge(opponent_stats, team_names, on='abbreviation')

opponent_stats['powerPlayPoints'] = opponent_stats['powerPlayGoals'] + opponent_stats['powerPlayAssists']

opponent_stats = opponent_stats.drop(columns=['powerPlayGoals', 'powerPlayAssists'])

opponent_stats
# Out:
#    abbreviation  timeOnIce  assists  goals  shots  hits  blocked  \
# 0           ANA     177245       59     30    324   135      129
# 1           ARI     176822       46     27    315   226      144
# 2           BOS     179094       29     16    300   204      159
# 3           BUF     177137       48     29    313   211      147
# 4           CAR     195199       63     39    287   167      208
# 5           CBJ     177997       51     32    324   116      181
# 6           CGY     176747       63     37    293   149      163
# 7           CHI     158981       57     32    308   151      146
# 8           COL     159656       31     21    258   138      147
# 9           DAL     162065       38     23    311   177      138
# 10          DET     195048       52     33    341   176      146
# 11          EDM     159462       64     36    268   180      147
# 12          FLA     159470       38     23    260   178      164
# 13          LAK     177600       52     31    277   211      175
# 14          MIN     177311       67     42    347   135      160
# 15          MTL     179977       49     31    352   171      143
# 16          NJD     160115       53     32    270   160      164
# 17          NSH     175926       52     30    290   195      141
# 18          NYI     159850       38     23    310   105      115
# 19          NYR     178145       32     19    263   152      139
# 20          OTT     157306       51     29    277   167      125
# 21          PHI     176281       57     33    267   139      150
# 22          PIT     158992       52     29    259   130      161
# 23          SEA     197535       57     35    359   186      190
# 24          SJS     177837       80     44    378   141      141
# 25          STL     142728       36     23    260   107       80
# 26          TBL     178350       52     32    349   138      156
# 27          TOR     179944       51     30    303   235      166
# 28          VAN     176820       34     22    305   192      161
# 29          VGK     197402       39     24    330   210      183
# 30          WPG     178696       59     35    288   192      179
# 31          WSH     161041       53     29    264   127      153
#
#     fantasyPoints  date  FPAPG  FPAPG_Rank                   name  id  \
# 0           247.4    10  24.74          19          Anaheim Ducks  24
# 1           240.1    10  24.01          22        Arizona Coyotes  53
# 2           192.4    10  19.24          31          Boston Bruins   6
# 3           239.9    10  23.99          23         Buffalo Sabres   7
# 4           307.9    11  27.99           6    Carolina Hurricanes  12
# 5           258.0    10  25.80          14  Columbus Blue Jackets  29
# 6           269.7    10  26.97           8         Calgary Flames  20
# 7           248.4     9  27.60           7     Chicago Blackhawks  16
# 8           189.1     9  21.01          29     Colorado Avalanche  21
# 9           208.3     9  23.14          24           Dallas Stars  25
# 10          253.7    11  23.06          25      Detroit Red Wings  17
# 11          270.3     9  30.03           2        Edmonton Oilers  22
# 12          222.8     9  24.76          17       Florida Panthers  13
# 13          261.3    10  26.13          12      Los Angeles Kings  26
# 14          299.2    10  29.92           3         Minnesota Wild  30
# 15          253.8    10  25.38          16     Montréal Canadiens   8
# 16          254.5     9  28.28           4      New Jersey Devils   1
# 17          246.0    10  24.60          21    Nashville Predators  18
# 18          191.5     9  21.28          28     New York Islanders   2
# 19          190.5    10  19.05          32       New York Rangers   3
# 20          229.9     9  25.54          15        Ottawa Senators   9
# 21          247.6    10  24.76          17    Philadelphia Flyers   4
# 22          237.4     9  26.38          10    Pittsburgh Penguins   5
# 23          291.0    11  26.45           9         Seattle Kraken  55
# 24          308.9    10  30.89           1        San Jose Sharks  28
# 25          166.7     8  20.84          30        St. Louis Blues  19
# 26          247.2    10  24.72          20    Tampa Bay Lightning  14
# 27          261.3    10  26.13          12    Toronto Maple Leafs  10
# 28          220.7    10  22.07          26      Vancouver Canucks  23
# 29          237.5    11  21.59          27   Vegas Golden Knights  54
# 30          282.5    10  28.25           5          Winnipeg Jets  52
# 31          237.1     9  26.34          11    Washington Capitals  15
#
#     powerPlayPoints
# 0                36
# 1                28
# 2                 3
# 3                12
# 4                29
# 5                15
# 6                 9
# 7                12
# 8                 6
# 9                 6
# 10               20
# 11               28
# 12               24
# 13               18
# 14               35
# 15               35
# 16               25
# 17               30
# 18               17
# 19               18
# 20               24
# 21               16
# 22               14
# 23               24
# 24               36
# 25               14
# 26                9
# 27               24
# 28               25
# 29                9
# 30               30
# 31               21

# %% [markdown]
# # Add opponent FPAPG by position

# %%
skaters_temp = skaters
# replace_dict = {'LW': 'W', 'RW': 'W'}
skaters_temp['position'] = skaters_temp['position'].replace('LW', 'W')
skaters_temp['position'] = skaters_temp['position'].replace('RW', 'W')
skaters_temp = skaters_temp.loc[skaters_temp['gamePlayed']>0]


opponent_stats_by_pos = skaters_temp.groupby(['opponent', 'position']).agg({
    'timeOnIce': 'sum',
    'assists': 'sum',
    'goals': 'sum',
    'shots': 'sum',
    'hits': 'sum',
    'blocked': 'sum',
    'fantasyPoints': 'sum',
    'date': 'nunique',
    'powerPlayGoals': 'sum',
    'powerPlayAssists': 'sum',
    'team': 'unique'
    # Add more columns as needed
})
opponent_stats_by_pos

opponent_stats_by_pos['powerPlayPoints'] = opponent_stats_by_pos['powerPlayGoals'] + opponent_stats_by_pos['powerPlayAssists']

opponent_stats_by_pos = opponent_stats_by_pos.drop(columns=['powerPlayGoals', 'powerPlayAssists'])

opponent_stats_by_pos = opponent_stats_by_pos.rename(columns={'date': 'gamesPlayed'})
opponent_stats_by_pos

D = opponent_stats_by_pos.xs('D', level='position')
D['position'] = 'D'
D['FPAPG'] = round(D['fantasyPoints'] / D['gamesPlayed'], 2)
D['FPAPG_Rank'] = D['FPAPG'].rank(ascending=False, method='min').astype(int)

C = opponent_stats_by_pos.xs('C', level='position')
C['position'] = 'C'
C['FPAPG'] = round(C['fantasyPoints'] / C['gamesPlayed'], 2)
C['FPAPG_Rank'] = C['FPAPG'].rank(ascending=False, method='min').astype(int)

W = opponent_stats_by_pos.xs('W', level='position')
W['position'] = 'W'
W['FPAPG'] = round(W['fantasyPoints'] / W['gamesPlayed'], 2)
W['FPAPG_Rank'] = W['FPAPG'].rank(ascending=False, method='min').astype(int)

skaters_temp['position'] = skaters_temp['position'].replace('W', 'F')
skaters_temp['position'] = skaters_temp['position'].replace('C', 'F')
opponent_stats_by_pos_f = skaters_temp.groupby(['opponent', 'position']).agg({
    'timeOnIce': 'sum',
    'assists': 'sum',
    'goals': 'sum',
    'shots': 'sum',
    'hits': 'sum',
    'blocked': 'sum',
    'fantasyPoints': 'sum',
    'date': 'nunique',
    'powerPlayGoals': 'sum',
    'powerPlayAssists': 'sum',
    'team': 'unique'
    # Add more columns as needed
})
opponent_stats_by_pos_f

opponent_stats_by_pos_f['powerPlayPoints'] = opponent_stats_by_pos_f['powerPlayGoals'] + opponent_stats_by_pos_f['powerPlayAssists']

opponent_stats_by_pos_f = opponent_stats_by_pos_f.drop(columns=['powerPlayGoals', 'powerPlayAssists'])

opponent_stats_by_pos_f = opponent_stats_by_pos_f.rename(columns={'date': 'gamesPlayed'})

F = opponent_stats_by_pos_f.xs('F', level='position')
F['position'] = 'F'
F['FPAPG'] = round(F['fantasyPoints'] / F['gamesPlayed'], 2)
F['FPAPG_Rank'] = F['FPAPG'].rank(ascending=False, method='min').astype(int)

F
# Out:
#           timeOnIce  assists  goals  shots  hits  blocked  fantasyPoints  \
# opponent
# ANA          108995       34     26    235    88       51          155.8
# ARI          107492       30     23    231   148       54          151.9
# BOS          110758       21     15    221   117       52          111.8
# BUF          108145       31     25    237   152       45          148.9
# CAR          119536       45     34    219    95      103          209.9
# CBJ          107912       35     26    241    76       69          159.2
# CGY          106789       41     29    214    88       56          162.2
# CHI           96345       43     28    226   105       44          161.1
# COL           98051       22     18    196    78       60          116.9
# DAL           99071       27     17    223   142       49          126.0
# DET          118593       31     28    257   120       49          158.2
# EDM           96920       43     32    211   114       51          176.5
# FLA           96877       33     18    191   105       74          146.1
# LAK          107322       35     27    206   143       43          154.4
# MIN          107398       40     38    260    94       67          199.4
# MTL          111017       37     31    273   105       55          180.3
# NJD           97748       38     24    203   101       62          155.9
# NSH          106129       34     26    208   123       42          151.6
# NYI           97867       29     16    224    72       41          118.1
# NYR          108294       20     15    188    94       50          109.7
# OTT           94741       34     23    203   108       53          147.1
# PHI          106291       46     26    188    84       63          163.2
# PIT           96610       39     26    197    89       71          161.6
# SEA          118835       32     32    254   123       64          175.2
# SJS          108085       45     38    274   103       60          202.2
# STL           85990       23     19    183    51       30          104.9
# TBL          107322       36     28    261    83       61          160.9
# TOR          109421       33     27    233   162       57          165.0
# VAN          107055       27     18    226   135       61          140.1
# VGK          120249       27     23    253   123       70          150.6
# WPG          108810       41     29    207   116       70          178.3
# WSH           98193       38     25    193    91       54          151.9
#
#           gamesPlayed                                               team  \
# opponent
# ANA                10           [VGK, CAR, DAL, ARI, BOS, CBJ, PHI, PIT]
# ARI                10           [NJD, NYR, NYI, STL, ANA, LAK, CHI, MTL]
# BOS                10           [CHI, NSH, SJS, LAK, ANA, DET, FLA, TOR]
# BUF                10      [NYR, NYI, TBL, CGY, MTL, OTT, NJD, COL, PHI]
# CAR                11      [OTT, LAK, ANA, SJS, SEA, COL, TBL, PHI, NYR]
# CBJ                10  [PHI, NYR, DET, CGY, MIN, ANA, MTL, NYI, DAL, ...
# CGY                10  [WPG, PIT, WSH, BUF, CBJ, DET, NYR, STL, EDM, ...
# CHI                 9                [PIT, BOS, MTL, TOR, COL, VGK, ARI]
# COL                 9      [LAK, SJS, SEA, CHI, CAR, NYI, PIT, BUF, STL]
# DAL                 9      [STL, VGK, ANA, PHI, PIT, TOR, CBJ, CGY, EDM]
# DET                11  [NJD, TBL, CBJ, PIT, OTT, CGY, SEA, WPG, BOS, ...
# EDM                 9           [VAN, NSH, PHI, WPG, MIN, NYR, CGY, DAL]
# FLA                 9      [MIN, WPG, NJD, TOR, VAN, SJS, SEA, BOS, DET]
# LAK                10      [COL, CAR, WPG, MIN, BOS, ARI, VGK, TOR, OTT]
# MIN                10      [FLA, TOR, MTL, LAK, CBJ, EDM, PHI, WSH, NJD]
# MTL                10  [TOR, CHI, MIN, WSH, BUF, NJD, CBJ, WPG, VGK, ...
# NJD                 9           [DET, ARI, FLA, NYI, MTL, WSH, BUF, MIN]
# NSH                10           [TBL, SEA, BOS, EDM, NYR, SJS, VAN, TOR]
# NYI                 9           [BUF, ARI, NJD, COL, OTT, CBJ, DET, WSH]
# NYR                10  [BUF, CBJ, ARI, NSH, SEA, CGY, EDM, VAN, WPG, ...
# OTT                 9      [CAR, PHI, TBL, WSH, DET, BUF, NYI, PIT, LAK]
# PHI                10  [CBJ, OTT, VAN, EDM, DAL, VGK, MIN, ANA, CAR, ...
# PIT                 9      [CHI, WSH, CGY, DET, STL, DAL, COL, OTT, ANA]
# SEA                11      [VGK, NSH, STL, COL, CAR, NYR, DET, FLA, TBL]
# SJS                10      [VGK, COL, CAR, BOS, NSH, FLA, TBL, WSH, VAN]
# STL                 8           [DAL, SEA, ARI, PIT, WPG, CGY, VAN, COL]
# TBL                10  [NSH, DET, OTT, BUF, VAN, TOR, CAR, SJS, SEA, ...
# TOR                10  [MTL, MIN, CHI, FLA, TBL, WSH, DAL, NSH, LAK, ...
# VAN                10           [EDM, PHI, TBL, FLA, NSH, STL, NYR, SJS]
# VGK                11      [SEA, SJS, ANA, DAL, WPG, CHI, PHI, LAK, MTL]
# WPG                10      [CGY, FLA, LAK, VGK, EDM, STL, DET, MTL, NYR]
# WSH                 9      [PIT, CGY, OTT, MTL, TOR, NJD, MIN, SJS, NYI]
#
#           powerPlayPoints position  FPAPG  FPAPG_Rank
# opponent
# ANA                    24        F  15.58          19
# ARI                    22        F  15.19          21
# BOS                     2        F  11.18          31
# BUF                    10        F  14.89          23
# CAR                    23        F  19.08           4
# CBJ                    10        F  15.92          18
# CGY                     6        F  16.22          15
# CHI                    10        F  17.90           7
# COL                     3        F  12.99          30
# DAL                     4        F  14.00          26
# DET                    16        F  14.38          24
# EDM                    20        F  19.61           3
# FLA                    19        F  16.23          14
# LAK                    15        F  15.44          20
# MIN                    26        F  19.94           2
# MTL                    30        F  18.03           5
# NJD                    17        F  17.32           9
# NSH                    23        F  15.16          22
# NYI                    14        F  13.12          28
# NYR                    13        F  10.97          32
# OTT                    16        F  16.34          12
# PHI                    11        F  16.32          13
# PIT                    11        F  17.96           6
# SEA                    16        F  15.93          17
# SJS                    27        F  20.22           1
# STL                     9        F  13.11          29
# TBL                     8        F  16.09          16
# TOR                    18        F  16.50          11
# VAN                    21        F  14.01          25
# VGK                     9        F  13.69          27
# WPG                    23        F  17.83           8
# WSH                    17        F  16.88          10

# %% [markdown]
# # Opponent goalie stats by FPAPG

# %%
gopponent_stats = goalies.groupby('opponent').agg({
    'timeOnIce': 'sum',
    'goals_against': 'sum',
    'shots': 'sum',
#     'fantasyPoints': ['sum', ('mean', lambda x: round(x.mean(), 2))],
    'fantasyPoints': 'sum',
    'date': 'nunique',
    'powerPlayGoals': 'sum',
    'powerPlayAssists': 'sum',
#     'team': 'unique',
    'powerPlaySaves': 'sum',
    'powerPlayShotsAgainst': 'sum'
    # Add more columns as needed
})

gopponent_stats['FPAPG'] = round(gopponent_stats['fantasyPoints'] / gopponent_stats['date'], 2)
gopponent_stats['FPAPG_Rank'] = gopponent_stats['FPAPG'].rank(ascending=False, method='min').astype(int)

# gopponent_stats['SPG'] = round(gopponent_stats['shots'] / gopponent_stats['date'], 2)
# gopponent_stats['SPG_Rank'] = gopponent_stats['SPG'].rank(ascending=False, method='min').astype(int)

gopponent_stats = gopponent_stats.rename_axis('abbreviation')

gopponent_stats = pd.merge(gopponent_stats, team_names, on='abbreviation')

# gopponent_stats['powerPlayPoints'] = gopponent_stats['powerPlayGoals'] + gopponent_stats['powerPlayAssists']

gopponent_stats = gopponent_stats.drop(columns=['powerPlayGoals', 'powerPlayAssists', 'id'])

gopponent_stats
# Out:
#    abbreviation  timeOnIce  goals_against  shots  fantasyPoints  date  \
# 0           ANA      36135           31.0    279            6.6    10
# 1           ARI      36174           33.0    297           10.8    10
# 2           BOS      35675           28.0    317            7.8    10
# 3           BUF      35840           29.0    282           13.6    10
# 4           CAR      40037           37.0    377           19.0    11
# 5           CBJ      36092           25.0    318           39.6    10
# 6           CGY      36081           21.0    327           54.2    10
# 7           CHI      32130           17.0    235           40.6     9
# 8           COL      32374           27.0    302           16.0     9
# 9           DAL      32574           28.0    264            1.2     9
# 10          DET      39686           37.0    329            8.4    11
# 11          EDM      32420           24.0    298           37.8     9
# 12          FLA      31834           20.0    298           34.6     9
# 13          LAK      36325           39.0    327           -4.4    10
# 14          MIN      36173           34.0    307           14.6    10
# 15          MTL      36646           29.0    299           19.0    10
# 16          NJD      32166           36.0    297           -6.8     9
# 17          NSH      35914           26.0    311           30.0    10
# 18          NYI      32091           24.0    285           20.2     9
# 19          NYR      36211           29.0    279            2.0    10
# 20          OTT      32180           33.0    301            7.6     9
# 21          PHI      35819           30.0    331           24.2    10
# 22          PIT      32265           25.0    323           33.6     9
# 23          SEA      40446           27.0    350           43.6    11
# 24          SJS      36192           10.0    252           74.4    10
# 25          STL      29210           13.0    200           35.4     8
# 26          TBL      36104           33.0    294           13.2    10
# 27          TOR      36731           30.0    333           22.6    10
# 28          VAN      35896           44.0    284          -25.0    10
# 29          VGK      40451           36.0    310          -10.2    11
# 30          WPG      36503           28.0    326           28.6    10
# 31          WSH      32764           15.0    267           48.4     9
#
#     powerPlaySaves  powerPlayShotsAgainst  FPAPG  FPAPG_Rank  \
# 0               41                     47   0.66          26
# 1               44                     54   1.08          22
# 2               50                     55   0.78          24
# 3               43                     46   1.36          20
# 4               57                     68   1.73          18
# 5               57                     62   3.96           7
# 6               54                     60   5.42           2
# 7               34                     37   4.51           4
# 8               46                     53   1.78          17
# 9               25                     28   0.13          28
# 10              48                     59   0.76          25
# 11              40                     47   4.20           6
# 12              64                     68   3.84           9
# 13              52                     60  -0.44          29
# 14              66                     72   1.46          19
# 15              47                     55   1.90          16
# 16              49                     66  -0.76          30
# 17              60                     70   3.00          11
# 18              38                     42   2.24          15
# 19              44                     56   0.20          27
# 20              60                     69   0.84          23
# 21              42                     46   2.42          13
# 22              52                     56   3.73          10
# 23              33                     41   3.96           7
# 24              29                     33   7.44           1
# 25              31                     32   4.43           5
# 26              47                     57   1.32          21
# 27              36                     46   2.26          14
# 28              41                     53  -2.50          32
# 29              42                     52  -0.93          31
# 30              46                     50   2.86          12
# 31              48                     51   5.38           3
#
#                      name
# 0           Anaheim Ducks
# 1         Arizona Coyotes
# 2           Boston Bruins
# 3          Buffalo Sabres
# 4     Carolina Hurricanes
# 5   Columbus Blue Jackets
# 6          Calgary Flames
# 7      Chicago Blackhawks
# 8      Colorado Avalanche
# 9            Dallas Stars
# 10      Detroit Red Wings
# 11        Edmonton Oilers
# 12       Florida Panthers
# 13      Los Angeles Kings
# 14         Minnesota Wild
# 15     Montréal Canadiens
# 16      New Jersey Devils
# 17    Nashville Predators
# 18     New York Islanders
# 19       New York Rangers
# 20        Ottawa Senators
# 21    Philadelphia Flyers
# 22    Pittsburgh Penguins
# 23         Seattle Kraken
# 24        San Jose Sharks
# 25        St. Louis Blues
# 26    Tampa Bay Lightning
# 27    Toronto Maple Leafs
# 28      Vancouver Canucks
# 29   Vegas Golden Knights
# 30          Winnipeg Jets
# 31    Washington Capitals

# %% [markdown]
# # Build module for Last five FP

# %% [markdown]
# ### This is built off last five games for the PLAYER, not for the TEAM

# %%
last_five_df = pd.DataFrame()

for player in player_list:
    temp_df = all_df.loc[all_df['name'] == player]
    temp_df = temp_df.sort_values('date', ascending=False)
    temp_df = temp_df.head(5)
    last_five_df = pd.concat([last_five_df, temp_df])
    
last_five_df
# Out:
#                       timeOnIce  assists  goals  shots  hits  powerPlayGoals  \
# ID8473575-02-11-2023       3600        0      0     32     0               0
# ID8473575-28-10-2023       3600        0      0     34     0               0
# ID8473575-21-10-2023       3547        0      0     42     0               0
# ID8480280-02-11-2023       3900        0      0     35     0               0
# ID8480280-28-10-2023       3600        0      0     24     0               0
# ...                         ...      ...    ...    ...   ...             ...
# ID8481611-21-10-2023       3417        0      0     27     0               0
# ID8481611-19-10-2023       2200        0      0     17     0               0
# ID8481035-01-11-2023       2956        0      0      9     0               0
# ID8481035-28-10-2023       3572        0      0     25     0               0
# ID8481035-21-10-2023       3733        0      0     25     0               0
#
#                       powerPlayAssists  penaltyMinutes faceOffPct  \
# ID8473575-02-11-2023                 0               0        NaN
# ID8473575-28-10-2023                 0               0        NaN
# ID8473575-21-10-2023                 0               0        NaN
# ID8480280-02-11-2023                 0               0        NaN
# ID8480280-28-10-2023                 0               0        NaN
# ...                                ...             ...        ...
# ID8481611-21-10-2023                 0               0        NaN
# ID8481611-19-10-2023                 0               0        NaN
# ID8481035-01-11-2023                 0               0        NaN
# ID8481035-28-10-2023                 0               0        NaN
# ID8481035-21-10-2023                 0               0        NaN
#
#                       faceOffWins  ...  shortHandedSavePercentage  \
# ID8473575-02-11-2023            0  ...                      100.0
# ID8473575-28-10-2023            0  ...                      100.0
# ID8473575-21-10-2023            0  ...                      100.0
# ID8480280-02-11-2023            0  ...                      100.0
# ID8480280-28-10-2023            0  ...                      100.0
# ...                           ...  ...                        ...
# ID8481611-21-10-2023            0  ...                       50.0
# ID8481611-19-10-2023            0  ...                        NaN
# ID8481035-01-11-2023            0  ...                        NaN
# ID8481035-28-10-2023            0  ...                       50.0
# ID8481035-21-10-2023            0  ...                        NaN
#
#                       evenStrengthSavePercentage  shutout  gamePlayed  \
# ID8473575-02-11-2023                       100.0        1         1.0
# ID8473575-28-10-2023                       100.0        1         1.0
# ID8473575-21-10-2023                   90.909091        0         1.0
# ID8480280-02-11-2023                   93.333333        0         1.0
# ID8480280-28-10-2023                   94.736842        0         1.0
# ...                                          ...      ...         ...
# ID8481611-21-10-2023                   88.888889        0         1.0
# ID8481611-19-10-2023                   88.235294        0         1.0
# ID8481035-01-11-2023                        75.0        0         1.0
# ID8481035-28-10-2023                   78.947368        0         1.0
# ID8481035-21-10-2023                        80.0        0         1.0
#
#                       fantasyPoints  specialTeams  shots_against  \
# ID8473575-02-11-2023           13.4           NaN           32.0
# ID8473575-28-10-2023           13.8           NaN           34.0
# ID8473575-21-10-2023            1.8           NaN           42.0
# ID8480280-02-11-2023            6.6           NaN           35.0
# ID8480280-28-10-2023            6.6           NaN           24.0
# ...                             ...           ...            ...
# ID8481611-21-10-2023           -7.8           NaN           27.0
# ID8481611-19-10-2023           -1.0           NaN           17.0
# ID8481035-01-11-2023           -2.6           NaN            9.0
# ID8481035-28-10-2023          -10.4           NaN           25.0
# ID8481035-21-10-2023           -5.0           NaN           25.0
#
#                       goals_against  decisionPoints  wins
# ID8473575-02-11-2023            0.0             4.0   1.0
# ID8473575-28-10-2023            0.0             4.0   1.0
# ID8473575-21-10-2023            3.0             0.0   0.0
# ID8480280-02-11-2023            2.0             4.0   1.0
# ID8480280-28-10-2023            1.0             4.0   1.0
# ...                             ...             ...   ...
# ID8481611-21-10-2023            6.0             0.0   0.0
# ID8481611-19-10-2023            2.0             0.0   0.0
# ID8481035-01-11-2023            2.0             0.0   0.0
# ID8481035-28-10-2023            7.0             0.0   0.0
# ID8481035-21-10-2023            5.0             1.0   0.0
#
# [3438 rows x 49 columns]

# %% [markdown]
# ### Let's build one for team's last five games

# %%
team_names

last_five_df_team = pd.DataFrame()

for index, row in team_names.iterrows():
    temp_all = all_df.loc[all_df['team'] == row['abbreviation']].sort_values('date', ascending=False)
    five_dates = temp_all['date'].unique()[:5]
    temp_filtered = temp_all[temp_all['date'].isin(five_dates)]
    last_five_df_team = pd.concat([last_five_df_team, temp_filtered])
    
last_five_df_team
# Out:
#                       timeOnIce  assists  goals  shots  hits  powerPlayGoals  \
# ID8482110-02-11-2023        950        0      0      2     0               0
# ID8477970-02-11-2023       3600        0      0     25     0               0
# ID8479407-02-11-2023       1058        3      1      2     2               1
# ID8477508-02-11-2023        847        0      0      2     0               0
# ID8479414-02-11-2023        504        1      0      1     2               0
# ...                         ...      ...    ...    ...   ...             ...
# ID8477505-24-10-2023       1411        1      0      1     0               0
# ID8478407-24-10-2023       1512        2      0      0     0               0
# ID8479977-24-10-2023        419        0      0      1     0               0
# ID8475768-24-10-2023       1024        0      2      5     0               1
# ID8476826-24-10-2023       1034        0      0      1     1               0
#
#                       powerPlayAssists  penaltyMinutes faceOffPct  \
# ID8482110-02-11-2023                 0               0        NaN
# ID8477970-02-11-2023                 0               0        NaN
# ID8479407-02-11-2023                 2               0        0.0
# ID8477508-02-11-2023                 0               0      100.0
# ID8479414-02-11-2023                 0               2        NaN
# ...                                ...             ...        ...
# ID8477505-24-10-2023                 0               2      61.54
# ID8478407-24-10-2023                 1               0        NaN
# ID8479977-24-10-2023                 0               0      100.0
# ID8475768-24-10-2023                 0               0       60.0
# ID8476826-24-10-2023                 0               0      58.33
#
#                       faceOffWins  ...  shortHandedSavePercentage  \
# ID8482110-02-11-2023            0  ...                        NaN
# ID8477970-02-11-2023            0  ...                        NaN
# ID8479407-02-11-2023            0  ...                        NaN
# ID8477508-02-11-2023            3  ...                        NaN
# ID8479414-02-11-2023            0  ...                        NaN
# ...                           ...  ...                        ...
# ID8477505-24-10-2023            8  ...                        NaN
# ID8478407-24-10-2023            0  ...                        NaN
# ID8479977-24-10-2023            1  ...                        NaN
# ID8475768-24-10-2023            3  ...                        NaN
# ID8476826-24-10-2023            7  ...                        NaN
#
#                       evenStrengthSavePercentage  shutout  gamePlayed  \
# ID8482110-02-11-2023                         NaN        0         1.0
# ID8477970-02-11-2023                    90.47619        0         1.0
# ID8479407-02-11-2023                         NaN        0         1.0
# ID8477508-02-11-2023                         NaN        0         1.0
# ID8479414-02-11-2023                         NaN        0         1.0
# ...                                          ...      ...         ...
# ID8477505-24-10-2023                         NaN        0         1.0
# ID8478407-24-10-2023                         NaN        0         1.0
# ID8479977-24-10-2023                         NaN        0         1.0
# ID8475768-24-10-2023                         NaN        0         1.0
# ID8476826-24-10-2023                         NaN        0         1.0
#
#                       fantasyPoints  specialTeams  shots_against  \
# ID8482110-02-11-2023            0.7           0.0            NaN
# ID8477970-02-11-2023            2.4           NaN           25.0
# ID8479407-02-11-2023            6.9           3.0            NaN
# ID8477508-02-11-2023            1.7           0.0            NaN
# ID8479414-02-11-2023            1.8           0.0            NaN
# ...                             ...           ...            ...
# ID8477505-24-10-2023            2.1           0.0            NaN
# ID8478407-24-10-2023            2.5           1.0            NaN
# ID8479977-24-10-2023            0.1           0.0            NaN
# ID8475768-24-10-2023            5.0           1.0            NaN
# ID8476826-24-10-2023            0.7           0.0            NaN
#
#                       goals_against  decisionPoints  wins
# ID8482110-02-11-2023            NaN             NaN   NaN
# ID8477970-02-11-2023            3.0             4.0   1.0
# ID8479407-02-11-2023            NaN             NaN   NaN
# ID8477508-02-11-2023            NaN             NaN   NaN
# ID8479414-02-11-2023            NaN             NaN   NaN
# ...                             ...             ...   ...
# ID8477505-24-10-2023            NaN             NaN   NaN
# ID8478407-24-10-2023            NaN             NaN   NaN
# ID8479977-24-10-2023            NaN             NaN   NaN
# ID8475768-24-10-2023            NaN             NaN   NaN
# ID8476826-24-10-2023            NaN             NaN   NaN
#
# [3052 rows x 49 columns]

# %%
# Build summary stats for rankings

def first_non_na_position(x):
    non_na_values = x[x != 'N/A']
    return non_na_values.iloc[0] if not non_na_values.empty else 'N/A'

summary_stats_last5 = last_five_df_team.groupby('id').agg({
    'name': 'first',
    'team': 'first',
    'position': first_non_na_position,
    'timeOnIce': 'sum',
    'gamePlayed': 'sum',
    'goals': 'sum',
    'assists': 'sum',
    'specialTeams': 'sum',
    'shots': 'sum',
    'hits': 'sum',
    'blocked': 'sum',
    'evenTimeOnIce': 'sum',
    'powerPlayTimeOnIce': 'sum',
    'shortHandedTimeOnIce': 'sum',
    'saves': 'sum',
    'powerPlaySaves': 'sum',
    'shortHandedSaves': 'sum',
    'evenSaves': 'sum',
    'shortHandedShotsAgainst': 'sum',
    'evenShotsAgainst': 'sum',
    'powerPlayShotsAgainst': 'sum',
    'decisionPoints': 'sum',
    'wins': 'sum',
    # 'decision': 'sum',
    'shutout': 'sum',
    'fantasyPoints': 'sum'
}).reset_index()


# summary_stats = summary_stats.rename(columns={'date': 'gp'})
# summary_stats['gp'] = summary_stats['gp'].apply(lambda x: len(x))
summary_stats_last5['gamePlayed'] = summary_stats_last5['gamePlayed'].astype(int)
summary_stats_last5['decisionPoints'] = summary_stats_last5['decisionPoints'].astype(int)
summary_stats_last5['wins'] = summary_stats_last5['wins'].astype(int)
summary_stats_last5['specialTeams'] = summary_stats_last5['specialTeams'].astype(int)


summary_stats_last5['FPP60'] = (summary_stats_last5['fantasyPoints'] / summary_stats_last5['timeOnIce'] * 3600).round(2)
summary_stats_last5['FPPG'] = (summary_stats_last5['fantasyPoints'] / summary_stats_last5['gamePlayed']).round(2)

summary_stats_last5 = summary_stats_last5.sort_values(by='FPPG', ascending=False)
# pd.set_option('display.max_rows', None)
summary_stats_last5.set_index('name', inplace=True)

player_list = summary_stats.index.to_list()



summary_stats_last5 = summary_stats_last5.merge(rostership, on='name', how='left')

summary_stats_last5.set_index('name', inplace=True)

summary_stats_last5.head()
# Out:
#                         id team position  timeOnIce  gamePlayed  goals  \
# name
# Semyon Varlamov  ID8473575  NYI        G       7200           2      0
# Jonathan Quick   ID8471734  NYR        G       3585           1      0
# Joel Hofer       ID8480981  STL        G       3596           1      0
# Antti Raanta     ID8477293  CAR        G       3600           1      0
# Jeremy Swayman   ID8480280  BOS        G      11089           3      0
#
#                  assists  specialTeams  shots  hits  ...  \
# name                                                 ...
# Semyon Varlamov        0             0     66     0  ...
# Jonathan Quick         0             0     29     0  ...
# Joel Hofer             0             0     27     0  ...
# Antti Raanta           0             0     20     0  ...
# Jeremy Swayman         0             0     82     0  ...
#
#                  shortHandedShotsAgainst  evenShotsAgainst  \
# name
# Semyon Varlamov                        2                55
# Jonathan Quick                         1                27
# Joel Hofer                             0                26
# Antti Raanta                           1                16
# Jeremy Swayman                         4                70
#
#                  powerPlayShotsAgainst  decisionPoints  wins  shutout  \
# name
# Semyon Varlamov                      9               8     2        2
# Jonathan Quick                       1               4     1        1
# Joel Hofer                           1               4     1        1
# Antti Raanta                         3               4     1        1
# Jeremy Swayman                       8              12     3        1
#
#                  fantasyPoints  FPP60   FPPG   rostered
# name
# Semyon Varlamov           27.2  13.60  13.60   3.297906
# Jonathan Quick            12.8  12.85  12.80   7.526228
# Joel Hofer                12.4  12.41  12.40   0.682755
# Antti Raanta              11.0  11.00  11.00   4.473232
# Jeremy Swayman            24.8   8.05   8.27  91.198115
#
# [5 rows x 28 columns]

# %%
summary_stats_last5_avail = summary_stats_last5.loc[summary_stats_last5['rostered'] <= 60]

# summary_stats_last5_avail_effective = summary_stats_last5_avail.loc[summary_stats_last5_avail['FPPG'] >= 1.5]

# %%
summary_stats_last5_avail = summary_stats_last5_avail.loc[summary_stats_last5_avail['position'] != 'G']

top_players_by_team = summary_stats_last5_avail.groupby('team').apply(lambda x: x.nlargest(5, 'fantasyPoints'))
top_players_by_team.reset_index(level='team', drop=True, inplace=True)

top_players_by_team = top_players_by_team.loc[top_players_by_team['FPPG'] >= 1.7]

top_players_by_team.loc[top_players_by_team['team'] == 'EDM']
# Out:
#                      id team position  timeOnIce  gamePlayed  goals  assists  \
# name
# Evander Kane  ID8475169  EDM       LW       5789           5      3        4
# Sam Gagner    ID8474040  EDM        C        780           1      2        0
#
#               specialTeams  shots  hits  ...  shortHandedShotsAgainst  \
# name                                     ...
# Evander Kane             1     19    23  ...                        0
# Sam Gagner               0      5     3  ...                        0
#
#               evenShotsAgainst  powerPlayShotsAgainst  decisionPoints  wins  \
# name
# Evander Kane                 0                      0               0     0
# Sam Gagner                   0                      0               0     0
#
#               shutout  fantasyPoints  FPP60  FPPG   rostered
# name
# Evander Kane        0           15.2   9.45  3.04  46.615046
# Sam Gagner          0            4.8  22.15  4.80   0.059212
#
# [2 rows x 28 columns]

# %%
goalies_summary_last_5 = summary_stats_last5.loc[summary_stats_last5['position'] == "G"]
goalies_summary_last_5 = goalies_summary_last_5.drop(columns=['goals',	'assists',	'specialTeams',	'hits',	'blocked',	'evenTimeOnIce',	'powerPlayTimeOnIce',	'shortHandedTimeOnIce'])
goalies_summary_last_5
# Out:
#                         id team position  timeOnIce  gamePlayed  shots  saves  \
# name
# Semyon Varlamov  ID8473575  NYI        G       7200           2     66     66
# Jonathan Quick   ID8471734  NYR        G       3585           1     29     29
# Joel Hofer       ID8480981  STL        G       3596           1     27     27
# Antti Raanta     ID8477293  CAR        G       3600           1     20     20
# Jeremy Swayman   ID8480280  BOS        G      11089           3     82     79
# ...                    ...  ...      ...        ...         ...    ...    ...
# Samuel Ersson    ID8481035  PHI        G       6528           2     34     25
# Jack Campbell    ID8475789  EDM        G       3557           1     31     25
# Dan Vladar       ID8478435  CGY        G       3591           1     30     24
# Anton Forsberg   ID8476341  OTT        G       2400           1     18     13
# Arvid Soderblom  ID8482821  CHI        G       5726           2     46     34
#
#                  powerPlaySaves  shortHandedSaves  evenSaves  \
# name
# Semyon Varlamov               9                 2         55
# Jonathan Quick                1                 1         27
# Joel Hofer                    1                 0         26
# Antti Raanta                  3                 1         16
# Jeremy Swayman                8                 4         67
# ...                         ...               ...        ...
# Samuel Ersson                 3                 1         21
# Jack Campbell                 7                 1         17
# Dan Vladar                    9                 0         15
# Anton Forsberg                1                 0         12
# Arvid Soderblom               3                 1         30
#
#                  shortHandedShotsAgainst  evenShotsAgainst  \
# name
# Semyon Varlamov                        2                55
# Jonathan Quick                         1                27
# Joel Hofer                             0                26
# Antti Raanta                           1                16
# Jeremy Swayman                         4                70
# ...                                  ...               ...
# Samuel Ersson                          2                27
# Jack Campbell                          1                23
# Dan Vladar                             0                21
# Anton Forsberg                         0                16
# Arvid Soderblom                        1                39
#
#                  powerPlayShotsAgainst  decisionPoints  wins  shutout  \
# name
# Semyon Varlamov                      9               8     2        2
# Jonathan Quick                       1               4     1        1
# Joel Hofer                           1               4     1        1
# Antti Raanta                         3               4     1        1
# Jeremy Swayman                       8              12     3        1
# ...                                ...             ...   ...      ...
# Samuel Ersson                        5               0     0        0
# Jack Campbell                        7               0     0        0
# Dan Vladar                           9               0     0        0
# Anton Forsberg                       2               0     0        0
# Arvid Soderblom                      6               0     0        0
#
#                  fantasyPoints  FPP60   FPPG   rostered
# name
# Semyon Varlamov           27.2  13.60  13.60   3.297906
# Jonathan Quick            12.8  12.85  12.80   7.526228
# Joel Hofer                12.4  12.41  12.40   0.682755
# Antti Raanta              11.0  11.00  11.00   4.473232
# Jeremy Swayman            24.8   8.05   8.27  91.198115
# ...                        ...    ...    ...        ...
# Samuel Ersson            -13.0  -7.17  -6.50   0.182457
# Jack Campbell             -7.0  -7.08  -7.00   8.211304
# Dan Vladar                -7.2  -7.22  -7.20   0.307164
# Anton Forsberg            -7.4 -11.10  -7.40   3.442351
# Arvid Soderblom          -17.2 -10.81  -8.60   1.392880
#
# [67 rows x 20 columns]

# %% [markdown]
# # Create a DataFrame of the sked

# %%
# Create a list to store game information
game_info = []

# Iterate through the dates
for date_info in days[1:4]:
        
    games = date_info['games']
    for game in games:
        
        date = game['gameDate']

        datetime_obj = datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ')

        utc_timestamp = pytz.utc.localize(datetime_obj)
        eastern_timezone = pytz.timezone('US/Eastern')
        eastern_time = utc_timestamp.astimezone(eastern_timezone)

        formatted_date_string = eastern_time.strftime('%d-%m-%Y')
        
        game_info.append({
            'Game ID': game['gamePk'],
            'Date': formatted_date_string,
            'Home Team': game['teams']['home']['team']['name'],
            'Home': team_names.loc[team_names['name'] == game['teams']['home']['team']['name']]['abbreviation'].iloc[0],
#             'HomeQB': opponent_QBs.loc[opponent_QBs['name'] == game['teams']['home']['team']['name']]['FPAPG'].iloc[0],
            'Away Team': game['teams']['away']['team']['name'],
            'Away': team_names.loc[team_names['name'] == game['teams']['away']['team']['name']]['abbreviation'].iloc[0],
#             'AwayQB': opponent_QBs.loc[opponent_QBs['name'] == game['teams']['away']['team']['name']]['FPAPG'].iloc[0],
        })

# Create a DataFrame
df = pd.DataFrame(game_info)


df.rename(columns={'Home Team': 'focusTeam', 'Date': 'date', 'Home': 'focus'}, inplace=True)
df_temp = df[['Game ID', 'date', 'Away Team', 'Away', 'focusTeam', 'focus']]
df_temp.rename(columns={'focusTeam': 'opponent', 'Date': 'date', 'focus': 'opp', 'Away Team': 'focusTeam', 'Away': 'focus'}, inplace=True)
df.rename(columns={'Away Team': 'opponent', 'Away': 'opp'}, inplace=True)
df['H/A'] = 'H'
df_temp['H/A'] = 'A'
df = pd.concat([df, df_temp])
df

sked_stats = df
sked_stats.reset_index(inplace=True)

# %%
# sked_stats['Dforecast'] = D.loc[]



for index, row in sked_stats.iterrows():
    d = D.loc[D.index == row['opp']]['FPAPG'][0]
#     drank = D.loc[D.index == row['focus']]['FPAPG_Rank'][0]
    c = C.loc[C.index == row['opp']]['FPAPG'][0]
#     crank = C.loc[C.index == row['focus']]['FPAPG_Rank'][0]
    w = W.loc[W.index == row['opp']]['FPAPG'][0]
#     wrank = W.loc[W.index == row['focus']]['FPAPG_Rank'][0]
    g = gopponent_stats.loc[gopponent_stats['abbreviation'] == row['opp']]['FPAPG'].iloc[0]
    
    sked_stats.at[index, 'D_FPAPG'] = d
#     sked_stats.at[index, 'D_RANK'] = drank
    sked_stats.at[index, 'C_FPAPG'] = c
#     sked_stats.at[index, 'C_RANK'] = crank
    sked_stats.at[index, 'W_FPAPG'] = w
#     sked_stats.at[index, 'W_RANK'] = wrank
    sked_stats.at[index, 'G_FPAPG'] = g
    
sked_stats.groupby('focusTeam').sum().sort_values('D_FPAPG', ascending=False)
# Out:
#                        index     Game ID  D_FPAPG  C_FPAPG  W_FPAPG  G_FPAPG
# focusTeam
# Philadelphia Flyers        9  4046040320    19.79    13.58    16.75     0.92
# Chicago Blackhawks        28  4046040342    19.48    16.86    16.69     3.08
# St. Louis Blues            5  4046040322    18.31    19.25    16.10     1.14
# Buffalo Sabres             7  4046040322    18.07    15.35    17.47     4.68
# New Jersey Devils         18  4046040332    17.42    16.89    14.12     8.94
# Vegas Golden Knights      34  4046040348    17.18    13.93    14.64     2.44
# Seattle Kraken            13  2023020170    10.75     6.78     9.44     5.42
# Pittsburgh Penguins       14  2023020171    10.67    10.18    10.04     7.44
# Calgary Flames            13  2023020170    10.53     9.16     6.76     3.96
# Nashville Predators        2  2023020159    10.42     9.79     9.82     4.20
# Arizona Coyotes            3  2023020160    10.42     9.67     8.16     2.86
# New York Rangers          12  2023020169     9.98     8.08    11.86     1.46
# Washington Capitals        8  2023020166     9.88     7.52     8.40     3.96
# Florida Panthers          11  2023020168     9.70     9.90     8.00     4.51
# Columbus Blue Jackets      8  2023020166     9.47     8.88     8.00     5.38
# Edmonton Oilers            2  2023020159     9.44     6.39     8.77     3.00
# Tampa Bay Lightning        6  2023020162     9.20     8.07     8.28     0.84
# Vancouver Canucks         15  2023020172     9.14     7.10     6.90     0.13
# Toronto Maple Leafs        7  2023020165     9.10     6.57     8.32     1.36
# New York Islanders        10  2023020167     8.91     7.62    11.46     1.73
# Winnipeg Jets              3  2023020160     8.82     6.57     8.62     1.08
# Boston Bruins              5  2023020161     8.68     7.82     6.56     0.76
# Ottawa Senators            6  2023020162     8.63     7.36     8.73     1.32
# Los Angeles Kings          9  2023020163     8.44     7.49     8.83     2.42
# San Jose Sharks           14  2023020171     8.42     9.02     8.93     3.73
# Carolina Hurricanes       10  2023020167     8.16     6.03     7.09     2.24
# Minnesota Wild            12  2023020169     8.08     5.75     5.22     0.20
# Detroit Red Wings          5  2023020161     8.06     6.94     4.24     0.78
# Dallas Stars              15  2023020172     8.06     8.15     5.86    -2.50
# Colorado Avalanche        16  2023020173     7.90     6.66     7.03    -0.93
# Anaheim Ducks             18  2023020175     7.90     6.66     7.03    -0.93
# Montréal Canadiens         4  2023020164     7.72     6.99     6.12     4.43

# %%
sked_stats
# Out:
#     index     Game ID        date              focusTeam focus  \
# 0       0  2023020157  03-11-2023         Buffalo Sabres   BUF
# 1       1  2023020158  03-11-2023        St. Louis Blues   STL
# 2       2  2023020159  04-11-2023        Edmonton Oilers   EDM
# 3       3  2023020160  04-11-2023        Arizona Coyotes   ARI
# 4       4  2023020164  04-11-2023        St. Louis Blues   STL
# 5       5  2023020161  04-11-2023      Detroit Red Wings   DET
# 6       6  2023020162  04-11-2023        Ottawa Senators   OTT
# 7       7  2023020165  04-11-2023    Toronto Maple Leafs   TOR
# 8       8  2023020166  04-11-2023    Washington Capitals   WSH
# 9       9  2023020163  04-11-2023    Philadelphia Flyers   PHI
# 10     10  2023020167  04-11-2023     New York Islanders   NYI
# 11     11  2023020168  04-11-2023     Chicago Blackhawks   CHI
# 12     12  2023020169  04-11-2023         Minnesota Wild   MIN
# 13     13  2023020170  04-11-2023         Seattle Kraken   SEA
# 14     14  2023020171  04-11-2023        San Jose Sharks   SJS
# 15     15  2023020172  04-11-2023      Vancouver Canucks   VAN
# 16     16  2023020173  04-11-2023   Vegas Golden Knights   VGK
# 17     17  2023020174  05-11-2023     Chicago Blackhawks   CHI
# 18     18  2023020175  05-11-2023          Anaheim Ducks   ANA
# 19      0  2023020157  03-11-2023    Philadelphia Flyers   PHI
# 20      1  2023020158  03-11-2023      New Jersey Devils   NJD
# 21      2  2023020159  04-11-2023    Nashville Predators   NSH
# 22      3  2023020160  04-11-2023          Winnipeg Jets   WPG
# 23      4  2023020164  04-11-2023     Montréal Canadiens   MTL
# 24      5  2023020161  04-11-2023          Boston Bruins   BOS
# 25      6  2023020162  04-11-2023    Tampa Bay Lightning   TBL
# 26      7  2023020165  04-11-2023         Buffalo Sabres   BUF
# 27      8  2023020166  04-11-2023  Columbus Blue Jackets   CBJ
# 28      9  2023020163  04-11-2023      Los Angeles Kings   LAK
# 29     10  2023020167  04-11-2023    Carolina Hurricanes   CAR
# 30     11  2023020168  04-11-2023       Florida Panthers   FLA
# 31     12  2023020169  04-11-2023       New York Rangers   NYR
# 32     13  2023020170  04-11-2023         Calgary Flames   CGY
# 33     14  2023020171  04-11-2023    Pittsburgh Penguins   PIT
# 34     15  2023020172  04-11-2023           Dallas Stars   DAL
# 35     16  2023020173  04-11-2023     Colorado Avalanche   COL
# 36     17  2023020174  05-11-2023      New Jersey Devils   NJD
# 37     18  2023020175  05-11-2023   Vegas Golden Knights   VGK
#
#                  opponent  opp H/A  D_FPAPG  C_FPAPG  W_FPAPG  G_FPAPG
# 0     Philadelphia Flyers  PHI   H     8.44     7.49     8.83     2.42
# 1       New Jersey Devils  NJD   H    10.96     9.03     8.29    -0.76
# 2     Nashville Predators  NSH   H     9.44     6.39     8.77     3.00
# 3           Winnipeg Jets  WPG   H    10.42     9.67     8.16     2.86
# 4      Montréal Canadiens  MTL   H     7.35    10.22     7.81     1.90
# 5           Boston Bruins  BOS   H     8.06     6.94     4.24     0.78
# 6     Tampa Bay Lightning  TBL   H     8.63     7.36     8.73     1.32
# 7          Buffalo Sabres  BUF   H     9.10     6.57     8.32     1.36
# 8   Columbus Blue Jackets  CBJ   H     9.88     7.52     8.40     3.96
# 9       Los Angeles Kings  LAK   H    10.69     7.01     8.43    -0.44
# 10    Carolina Hurricanes  CAR   H     8.91     7.62    11.46     1.73
# 11       Florida Panthers  FLA   H     8.52     7.83     8.40     3.84
# 12       New York Rangers  NYR   H     8.08     5.75     5.22     0.20
# 13         Calgary Flames  CGY   H    10.75     6.78     9.44     5.42
# 14    Pittsburgh Penguins  PIT   H     8.42     9.02     8.93     3.73
# 15           Dallas Stars  DAL   H     9.14     7.10     6.90     0.13
# 16     Colorado Avalanche  COL   H     8.02     5.90     7.09     1.78
# 17      New Jersey Devils  NJD   H    10.96     9.03     8.29    -0.76
# 18   Vegas Golden Knights  VGK   H     7.90     6.66     7.03    -0.93
# 19         Buffalo Sabres  BUF   A     9.10     6.57     8.32     1.36
# 20        St. Louis Blues  STL   A     7.72     6.99     6.12     4.43
# 21        Edmonton Oilers  EDM   A    10.42     9.79     9.82     4.20
# 22        Arizona Coyotes  ARI   A     8.82     6.57     8.62     1.08
# 23        St. Louis Blues  STL   A     7.72     6.99     6.12     4.43
# 24      Detroit Red Wings  DET   A     8.68     7.82     6.56     0.76
# 25        Ottawa Senators  OTT   A     9.20     8.07     8.28     0.84
# 26    Toronto Maple Leafs  TOR   A     9.63     7.86     8.64     2.26
# 27    Washington Capitals  WSH   A     9.47     8.88     8.00     5.38
# 28    Philadelphia Flyers  PHI   A     8.44     7.49     8.83     2.42
# 29     New York Islanders  NYI   A     8.16     6.03     7.09     2.24
# 30     Chicago Blackhawks  CHI   A     9.70     9.90     8.00     4.51
# 31         Minnesota Wild  MIN   A     9.98     8.08    11.86     1.46
# 32         Seattle Kraken  SEA   A    10.53     9.16     6.76     3.96
# 33        San Jose Sharks  SJS   A    10.67    10.18    10.04     7.44
# 34      Vancouver Canucks  VAN   A     8.06     8.15     5.86    -2.50
# 35   Vegas Golden Knights  VGK   A     7.90     6.66     7.03    -0.93
# 36     Chicago Blackhawks  CHI   A     9.70     9.90     8.00     4.51
# 37          Anaheim Ducks  ANA   A     9.16     8.03     7.55     0.66

# %% [markdown]
# # Run the printout module

# %%
eastern = pytz.timezone('US/Eastern')

for day in days[1:4]:
    date = day['date']
    games = day['games']

    day_of_week = datetime.strptime(date, '%Y-%m-%d').strftime('%A').upper()
    print(day_of_week)

    for game in games:
        home_team = game['teams']['home']['team']['name']
        away_team = game['teams']['away']['team']['name']
        venue = game['venue']['name']
        game_time_utc = datetime.fromisoformat(game['gameDate'][:-1]).replace(tzinfo=pytz.utc)
        game_time_et = game_time_utc.astimezone(eastern)

        formatted_time = game_time_et.strftime('%I:%M %p').lstrip('0').replace(':00', '').replace('PM', 'p.m.')

        home_abbr = opponent_stats.loc[opponent_stats['name'] == home_team, 'abbreviation'].values[0]
        home_top5 = top_players_by_team.loc[top_players_by_team['team'] == home_abbr]
        home_goalies = goalies_summary_last_5.loc[goalies_summary_last_5['team'] == home_abbr]

        away_abbr = opponent_stats.loc[opponent_stats['name'] == away_team, 'abbreviation'].values[0]
        away_top5 = top_players_by_team.loc[top_players_by_team['team'] == away_abbr]
        away_goalies = goalies_summary_last_5.loc[goalies_summary_last_5['team'] == away_abbr]

#         print(f"On {date}, {away_team} at {home_team}")
        print(f"\033[1m{away_team} at {home_team}\033[0m")
        print(f"{formatted_time}, {venue}")
        print()
        print(f"\033[1mForwards against {home_abbr} score\033[0m: {F.loc[F.index == home_abbr, 'FPAPG'].values[0]} FPAPG, Rank: {F.loc[F.index == home_abbr, 'FPAPG_Rank'].values[0]}")
        print(f"\033[1mDefence against {home_abbr} score\033[0m: {D.loc[D.index == home_abbr, 'FPAPG'].values[0]} FPAPG, Rank: {D.loc[D.index == home_abbr, 'FPAPG_Rank'].values[0]}")
        print(f"\033[1mTop {away_abbr} Players Fantasy Points Last 5 (60% or fewer rosters)\033[0m")
        for index, row in away_top5.iterrows():
            print(f"{index}, {row['position']} ({round(row['rostered'], 2)}% rostered): {round(row['fantasyPoints'], 2)} fantasy points ({row['FPPG']} FPPG)")
        print()
        print(f"\033[1mGoalies against {home_abbr} score\033[0m: {gopponent_stats.loc[opponent_stats['name'] == home_team, 'FPAPG'].values[0]} FPAPG, Rank: {gopponent_stats.loc[opponent_stats['name'] == home_team, 'FPAPG_Rank'].values[0]}")
        for index, row in away_goalies.iterrows():
            print(f"{index} ({round(row['rostered'], 2)}% rostered) last five: {row['gamePlayed']} appearances, FPPG: {row['FPPG']}, FP: {round(row['fantasyPoints'], 2)}")
        print()
        print(f"\033[1mForwards against {away_abbr} score\033[0m: {F.loc[F.index == away_abbr, 'FPAPG'].values[0]} FPAPG, Rank: {F.loc[F.index == away_abbr, 'FPAPG_Rank'].values[0]}")
        print(f"\033[1mDefence against {away_abbr} score\033[0m: {D.loc[D.index == away_abbr, 'FPAPG'].values[0]} FPAPG, Rank: {D.loc[D.index == away_abbr, 'FPAPG_Rank'].values[0]}")
        print(f"\033[1mTop {home_abbr} Players Fantasy Points Last 5 (60% or fewer rosters)\033[0m")
        for index, row in home_top5.iterrows():
            print(f"{index}, {row['position']} ({round(row['rostered'], 2)}% rostered): {round(row['fantasyPoints'], 2)} fantasy points ({row['FPPG']} FPPG)")

        print()
        print(f"\033[1mGoalies against {away_abbr} score\033[0m: {gopponent_stats.loc[opponent_stats['name'] == away_team, 'FPAPG'].values[0]} FPAPG, Rank: {gopponent_stats.loc[opponent_stats['name'] == away_team, 'FPAPG_Rank'].values[0]}")
        for index, row in home_goalies.iterrows():
            print(f"{index} ({round(row['rostered'], 2)}% rostered) last five: {row['gamePlayed']} appearances, FPPG: {row['FPPG']}, FP: {round(row['fantasyPoints'], 2)}")
        print()
        print('-'*25)
        print()
#         print("\033[1mThis is bold text\033[0m")
# Out:
# FRIDAY
# Philadelphia Flyers at Buffalo Sabres
# 7 p.m., KeyBank Center
#
# Forwards against BUF score: 14.89 FPAPG, Rank: 23
# Defence against BUF score: 9.1 FPAPG, Rank: 17
# Top PHI Players Fantasy Points Last 5 (60% or fewer rosters)
# Travis Sanheim, D (52.99% rostered): 13.3 fantasy points (2.66 FPPG)
# Cam Atkinson, RW (27.6% rostered): 13.2 fantasy points (2.64 FPPG)
# Joel Farabee, LW (4.07% rostered): 8.8 fantasy points (1.76 FPPG)
# Bobby Brink, RW (2.45% rostered): 8.6 fantasy points (1.72 FPPG)
#
# Goalies against BUF score: 1.36 FPAPG, Rank: 20
# Carter Hart (80.66% rostered) last five: 4 appearances, FPPG: 0.2, FP: 0.8
# Samuel Ersson (0.18% rostered) last five: 2 appearances, FPPG: -6.5, FP: -13.0
#
# Forwards against PHI score: 16.32 FPAPG, Rank: 13
# Defence against PHI score: 8.44 FPAPG, Rank: 23
# Top BUF Players Fantasy Points Last 5 (60% or fewer rosters)
# Mattias Samuelsson, D (14.42% rostered): 11.7 fantasy points (2.34 FPPG)
# Casey Mittelstadt, C (6.34% rostered): 9.8 fantasy points (1.96 FPPG)
# Henri Jokiharju, D (0.54% rostered): 9.3 fantasy points (1.86 FPPG)
#
# Goalies against PHI score: 2.42 FPAPG, Rank: 13
# Ukko-Pekka Luukkonen (6.69% rostered) last five: 4 appearances, FPPG: 4.9, FP: 19.6
# Eric Comrie (0.55% rostered) last five: 2 appearances, FPPG: -1.0, FP: -2.0
#
# -------------------------
#
# New Jersey Devils at St. Louis Blues
# 8 p.m., Enterprise Center
#
# Forwards against STL score: 13.11 FPAPG, Rank: 29
# Defence against STL score: 7.72 FPAPG, Rank: 31
# Top NJD Players Fantasy Points Last 5 (60% or fewer rosters)
# Erik Haula, LW (15.58% rostered): 9.6 fantasy points (1.92 FPPG)
#
# Goalies against STL score: 4.43 FPAPG, Rank: 5
# Vitek Vanecek (81.35% rostered) last five: 5 appearances, FPPG: 2.28, FP: 11.4
# Akira Schmid (5.15% rostered) last five: 1 appearances, FPPG: -5.0, FP: -5.0
#
# Forwards against NJD score: 17.32 FPAPG, Rank: 9
# Defence against NJD score: 10.96 FPAPG, Rank: 1
# Top STL Players Fantasy Points Last 5 (60% or fewer rosters)
# Colton Parayko, D (59.73% rostered): 11.1 fantasy points (2.22 FPPG)
#
# Goalies against NJD score: -0.76 FPAPG, Rank: 30
# Joel Hofer (0.68% rostered) last five: 1 appearances, FPPG: 12.4, FP: 12.4
# Jordan Binnington (49.68% rostered) last five: 4 appearances, FPPG: -0.45, FP: -1.8
#
# -------------------------
#
# SATURDAY
# Nashville Predators at Edmonton Oilers
# 3 p.m., Rogers Place
#
# Forwards against EDM score: 19.61 FPAPG, Rank: 3
# Defence against EDM score: 10.42 FPAPG, Rank: 6
# Top NSH Players Fantasy Points Last 5 (60% or fewer rosters)
# Alexandre Carrier, D (23.37% rostered): 13.3 fantasy points (2.66 FPPG)
# Dante Fabbro, D (0.5% rostered): 11.3 fantasy points (2.26 FPPG)
# Ryan O'Reilly, C (45.08% rostered): 9.9 fantasy points (1.98 FPPG)
# Luke Evangelista, RW (10.26% rostered): 9.9 fantasy points (1.98 FPPG)
# Colton Sissons, C (11.14% rostered): 8.5 fantasy points (1.7 FPPG)
#
# Goalies against EDM score: 4.2 FPAPG, Rank: 6
# Juuse Saros (96.87% rostered) last five: 4 appearances, FPPG: 2.6, FP: 10.4
# Kevin Lankinen (0.68% rostered) last five: 1 appearances, FPPG: -3.6, FP: -3.6
#
# Forwards against NSH score: 15.16 FPAPG, Rank: 22
# Defence against NSH score: 9.44 FPAPG, Rank: 13
# Top EDM Players Fantasy Points Last 5 (60% or fewer rosters)
# Evander Kane, LW (46.62% rostered): 15.2 fantasy points (3.04 FPPG)
# Sam Gagner, C (0.06% rostered): 4.8 fantasy points (4.8 FPPG)
#
# Goalies against NSH score: 3.0 FPAPG, Rank: 11
# Stuart Skinner (49.9% rostered) last five: 4 appearances, FPPG: 0.25, FP: 1.0
# Jack Campbell (8.21% rostered) last five: 1 appearances, FPPG: -7.0, FP: -7.0
#
# -------------------------
#
# Winnipeg Jets at Arizona Coyotes
# 4 p.m., Mullett Arena
#
# Forwards against ARI score: 15.19 FPAPG, Rank: 21
# Defence against ARI score: 8.82 FPAPG, Rank: 19
# Top WPG Players Fantasy Points Last 5 (60% or fewer rosters)
# Nino Niederreiter, RW (3.2% rostered): 10.7 fantasy points (2.14 FPPG)
# Mason Appleton, C (1.44% rostered): 9.5 fantasy points (1.9 FPPG)
# Adam Lowry, C (1.66% rostered): 9.4 fantasy points (1.88 FPPG)
#
# Goalies against ARI score: 1.08 FPAPG, Rank: 22
# Connor Hellebuyck (99.33% rostered) last five: 4 appearances, FPPG: 2.1, FP: 8.4
# Laurent Brossoit (0.33% rostered) last five: 1 appearances, FPPG: 0.2, FP: 0.2
#
# Forwards against WPG score: 17.83 FPAPG, Rank: 8
# Defence against WPG score: 10.42 FPAPG, Rank: 6
# Top ARI Players Fantasy Points Last 5 (60% or fewer rosters)
# Jack McBain, C (4.94% rostered): 12.4 fantasy points (2.48 FPPG)
# Lawson Crouse, LW (47.19% rostered): 11.8 fantasy points (2.95 FPPG)
# Nick Bjugstad, C (1.34% rostered): 10.8 fantasy points (2.16 FPPG)
# Michael Carcone, LW (1.04% rostered): 10.6 fantasy points (2.12 FPPG)
# Nick Schmaltz, C (35.05% rostered): 9.9 fantasy points (1.98 FPPG)
#
# Goalies against WPG score: 2.86 FPAPG, Rank: 12
# Connor Ingram (1.31% rostered) last five: 3 appearances, FPPG: 2.87, FP: 8.6
# Karel Vejmelka (19.43% rostered) last five: 3 appearances, FPPG: -1.87, FP: -5.6
#
# -------------------------
#
# Montréal Canadiens at St. Louis Blues
# 7 p.m., Enterprise Center
#
# Forwards against STL score: 13.11 FPAPG, Rank: 29
# Defence against STL score: 7.72 FPAPG, Rank: 31
# Top MTL Players Fantasy Points Last 5 (60% or fewer rosters)
# Sean Monahan, C (17.06% rostered): 13.0 fantasy points (2.6 FPPG)
# Justin Barron, D (3.01% rostered): 11.7 fantasy points (2.34 FPPG)
# Kaiden Guhle, D (12.2% rostered): 8.6 fantasy points (2.87 FPPG)
#
# Goalies against STL score: 4.43 FPAPG, Rank: 5
# Jake Allen (15.04% rostered) last five: 2 appearances, FPPG: 3.4, FP: 6.8
# Sam Montembeault (1.96% rostered) last five: 2 appearances, FPPG: 3.1, FP: 6.2
# Cayden Primeau (0.07% rostered) last five: 1 appearances, FPPG: -2.2, FP: -2.2
#
# Forwards against MTL score: 18.03 FPAPG, Rank: 5
# Defence against MTL score: 7.35 FPAPG, Rank: 32
# Top STL Players Fantasy Points Last 5 (60% or fewer rosters)
# Colton Parayko, D (59.73% rostered): 11.1 fantasy points (2.22 FPPG)
#
# Goalies against MTL score: 1.9 FPAPG, Rank: 16
# Joel Hofer (0.68% rostered) last five: 1 appearances, FPPG: 12.4, FP: 12.4
# Jordan Binnington (49.68% rostered) last five: 4 appearances, FPPG: -0.45, FP: -1.8
#
# -------------------------
#
# Boston Bruins at Detroit Red Wings
# 7 p.m., Little Caesars Arena
#
# Forwards against DET score: 14.38 FPAPG, Rank: 24
# Defence against DET score: 8.68 FPAPG, Rank: 20
# Top BOS Players Fantasy Points Last 5 (60% or fewer rosters)
# Pavel Zacha, C (17.16% rostered): 13.6 fantasy points (2.72 FPPG)
# Charlie Coyle, C (3.97% rostered): 8.9 fantasy points (1.78 FPPG)
#
# Goalies against DET score: 0.76 FPAPG, Rank: 25
# Jeremy Swayman (91.2% rostered) last five: 3 appearances, FPPG: 8.27, FP: 24.8
# Linus Ullmark (98.93% rostered) last five: 2 appearances, FPPG: 2.8, FP: 5.6
#
# Forwards against BOS score: 11.18 FPAPG, Rank: 31
# Defence against BOS score: 8.06 FPAPG, Rank: 27
# Top DET Players Fantasy Points Last 5 (60% or fewer rosters)
#
# Goalies against BOS score: 0.78 FPAPG, Rank: 24
# James Reimer (14.07% rostered) last five: 2 appearances, FPPG: 1.0, FP: 2.0
# Ville Husso (37.04% rostered) last five: 3 appearances, FPPG: 0.8, FP: 2.4
#
# -------------------------
#
# Tampa Bay Lightning at Ottawa Senators
# 7 p.m., Canadian Tire Centre
#
# Forwards against OTT score: 16.34 FPAPG, Rank: 12
# Defence against OTT score: 9.2 FPAPG, Rank: 14
# Top TBL Players Fantasy Points Last 5 (60% or fewer rosters)
# Alex Barré-Boulet, C (0.59% rostered): 10.1 fantasy points (2.02 FPPG)
#
# Goalies against OTT score: 0.84 FPAPG, Rank: 23
# Jonas Johansson (63.49% rostered) last five: 4 appearances, FPPG: 7.1, FP: 28.4
# Matt Tomkins (0.1% rostered) last five: 1 appearances, FPPG: -1.2, FP: -1.2
#
# Forwards against TBL score: 16.09 FPAPG, Rank: 16
# Defence against TBL score: 8.63 FPAPG, Rank: 21
# Top OTT Players Fantasy Points Last 5 (60% or fewer rosters)
# Ridly Greig, C (3.6% rostered): 9.9 fantasy points (1.98 FPPG)
# Jacob Bernard-Docker, D (0.06% rostered): 9.7 fantasy points (1.94 FPPG)
# Travis Hamonic, D (0.61% rostered): 9.3 fantasy points (1.86 FPPG)
#
# Goalies against TBL score: 1.32 FPAPG, Rank: 21
# Joonas Korpisalo (35.43% rostered) last five: 5 appearances, FPPG: 0.96, FP: 4.8
# Anton Forsberg (3.44% rostered) last five: 1 appearances, FPPG: -7.4, FP: -7.4
#
# -------------------------
#
# Buffalo Sabres at Toronto Maple Leafs
# 7 p.m., Scotiabank Arena
#
# Forwards against TOR score: 16.5 FPAPG, Rank: 11
# Defence against TOR score: 9.63 FPAPG, Rank: 11
# Top BUF Players Fantasy Points Last 5 (60% or fewer rosters)
# Mattias Samuelsson, D (14.42% rostered): 11.7 fantasy points (2.34 FPPG)
# Casey Mittelstadt, C (6.34% rostered): 9.8 fantasy points (1.96 FPPG)
# Henri Jokiharju, D (0.54% rostered): 9.3 fantasy points (1.86 FPPG)
#
# Goalies against TOR score: 2.26 FPAPG, Rank: 14
# Ukko-Pekka Luukkonen (6.69% rostered) last five: 4 appearances, FPPG: 4.9, FP: 19.6
# Eric Comrie (0.55% rostered) last five: 2 appearances, FPPG: -1.0, FP: -2.0
#
# Forwards against BUF score: 14.89 FPAPG, Rank: 23
# Defence against BUF score: 9.1 FPAPG, Rank: 17
# Top TOR Players Fantasy Points Last 5 (60% or fewer rosters)
# Mark Giordano, D (9.32% rostered): 8.9 fantasy points (1.78 FPPG)
#
# Goalies against BUF score: 1.36 FPAPG, Rank: 20
# Joseph Woll (52.49% rostered) last five: 3 appearances, FPPG: 4.73, FP: 14.2
# Ilya Samsonov (75.63% rostered) last five: 2 appearances, FPPG: 1.9, FP: 3.8
#
# -------------------------
#
# Columbus Blue Jackets at Washington Capitals
# 7 p.m., Capital One Arena
#
# Forwards against WSH score: 16.88 FPAPG, Rank: 10
# Defence against WSH score: 9.47 FPAPG, Rank: 12
# Top CBJ Players Fantasy Points Last 5 (60% or fewer rosters)
# Emil Bemstrom, RW (0.15% rostered): 11.1 fantasy points (2.22 FPPG)
# Jack Roslovic, C (7.02% rostered): 10.4 fantasy points (2.08 FPPG)
# Adam Fantilli, C (44.9% rostered): 8.8 fantasy points (1.76 FPPG)
#
# Goalies against WSH score: 5.38 FPAPG, Rank: 3
# Spencer Martin (0.11% rostered) last five: 1 appearances, FPPG: 2.4, FP: 2.4
# Elvis Merzlikins (10.16% rostered) last five: 4 appearances, FPPG: 0.2, FP: 0.8
#
# Forwards against CBJ score: 15.92 FPAPG, Rank: 18
# Defence against CBJ score: 9.88 FPAPG, Rank: 9
# Top WSH Players Fantasy Points Last 5 (60% or fewer rosters)
# Tom Wilson, RW (22.86% rostered): 12.4 fantasy points (2.48 FPPG)
# Dylan Strome, C (57.31% rostered): 10.6 fantasy points (2.12 FPPG)
#
# Goalies against CBJ score: 3.96 FPAPG, Rank: 7
# Darcy Kuemper (25.89% rostered) last five: 4 appearances, FPPG: 2.0, FP: 8.0
# Hunter Shepard (0.04% rostered) last five: 1 appearances, FPPG: -0.4, FP: -0.4
#
# -------------------------
#
# Los Angeles Kings at Philadelphia Flyers
# 7:30 p.m., Wells Fargo Center
#
# Forwards against PHI score: 16.32 FPAPG, Rank: 13
# Defence against PHI score: 8.44 FPAPG, Rank: 23
# Top LAK Players Fantasy Points Last 5 (60% or fewer rosters)
# Mikey Anderson, D (13.84% rostered): 10.7 fantasy points (2.14 FPPG)
# Quinton Byfield, RW (4.99% rostered): 9.3 fantasy points (1.86 FPPG)
#
# Goalies against PHI score: 2.42 FPAPG, Rank: 13
# Cam Talbot (32.58% rostered) last five: 4 appearances, FPPG: 4.6, FP: 18.4
# Pheonix Copley (4.07% rostered) last five: 2 appearances, FPPG: -1.3, FP: -2.6
#
# Forwards against LAK score: 15.44 FPAPG, Rank: 20
# Defence against LAK score: 10.69 FPAPG, Rank: 3
# Top PHI Players Fantasy Points Last 5 (60% or fewer rosters)
# Travis Sanheim, D (52.99% rostered): 13.3 fantasy points (2.66 FPPG)
# Cam Atkinson, RW (27.6% rostered): 13.2 fantasy points (2.64 FPPG)
# Joel Farabee, LW (4.07% rostered): 8.8 fantasy points (1.76 FPPG)
# Bobby Brink, RW (2.45% rostered): 8.6 fantasy points (1.72 FPPG)
#
# Goalies against LAK score: -0.44 FPAPG, Rank: 29
# Carter Hart (80.66% rostered) last five: 4 appearances, FPPG: 0.2, FP: 0.8
# Samuel Ersson (0.18% rostered) last five: 2 appearances, FPPG: -6.5, FP: -13.0
#
# -------------------------
#
# Carolina Hurricanes at New York Islanders
# 7:30 p.m., UBS Arena
#
# Forwards against NYI score: 13.12 FPAPG, Rank: 28
# Defence against NYI score: 8.16 FPAPG, Rank: 25
# Top CAR Players Fantasy Points Last 5 (60% or fewer rosters)
#
# Goalies against NYI score: 2.24 FPAPG, Rank: 15
# Antti Raanta (4.47% rostered) last five: 1 appearances, FPPG: 11.0, FP: 11.0
# Frederik Andersen (69.14% rostered) last five: 3 appearances, FPPG: 3.6, FP: 10.8
# Pyotr Kochetkov (27.86% rostered) last five: 1 appearances, FPPG: -2.0, FP: -2.0
#
# Forwards against CAR score: 19.08 FPAPG, Rank: 4
# Defence against CAR score: 8.91 FPAPG, Rank: 18
# Top NYI Players Fantasy Points Last 5 (60% or fewer rosters)
# Ryan Pulock, D (3.08% rostered): 11.3 fantasy points (2.26 FPPG)
# Kyle Palmieri, C (7.99% rostered): 10.2 fantasy points (2.04 FPPG)
#
# Goalies against CAR score: 1.73 FPAPG, Rank: 18
# Semyon Varlamov (3.3% rostered) last five: 2 appearances, FPPG: 13.6, FP: 27.2
# Ilya Sorokin (98.55% rostered) last five: 3 appearances, FPPG: 1.6, FP: 4.8
#
# -------------------------
#
# Florida Panthers at Chicago Blackhawks
# 8 p.m., United Center
#
# Forwards against CHI score: 17.9 FPAPG, Rank: 7
# Defence against CHI score: 9.7 FPAPG, Rank: 10
# Top FLA Players Fantasy Points Last 5 (60% or fewer rosters)
# Niko Mikkola, D (2.47% rostered): 11.1 fantasy points (2.22 FPPG)
#
# Goalies against CHI score: 4.51 FPAPG, Rank: 4
# Anthony Stolarz (0.42% rostered) last five: 1 appearances, FPPG: 7.4, FP: 7.4
# Sergei Bobrovsky (48.25% rostered) last five: 4 appearances, FPPG: 3.6, FP: 14.4
#
# Forwards against FLA score: 16.23 FPAPG, Rank: 14
# Defence against FLA score: 8.52 FPAPG, Rank: 22
# Top CHI Players Fantasy Points Last 5 (60% or fewer rosters)
# Connor Murphy, D (2.55% rostered): 10.4 fantasy points (2.08 FPPG)
#
# Goalies against FLA score: 3.84 FPAPG, Rank: 9
# Petr Mrazek (9.19% rostered) last five: 4 appearances, FPPG: 0.75, FP: 3.0
# Arvid Soderblom (1.39% rostered) last five: 2 appearances, FPPG: -8.6, FP: -17.2
#
# -------------------------
#
# New York Rangers at Minnesota Wild
# 8 p.m., Xcel Energy Center
#
# Forwards against MIN score: 19.94 FPAPG, Rank: 2
# Defence against MIN score: 9.98 FPAPG, Rank: 8
# Top NYR Players Fantasy Points Last 5 (60% or fewer rosters)
# Nick Bonino, C (0.58% rostered): 9.8 fantasy points (1.96 FPPG)
# Braden Schneider, D (0.9% rostered): 9.2 fantasy points (1.84 FPPG)
#
# Goalies against MIN score: 1.46 FPAPG, Rank: 19
# Jonathan Quick (7.53% rostered) last five: 1 appearances, FPPG: 12.8, FP: 12.8
# Igor Shesterkin (99.73% rostered) last five: 4 appearances, FPPG: 5.9, FP: 23.6
#
# Forwards against NYR score: 10.97 FPAPG, Rank: 32
# Defence against NYR score: 8.08 FPAPG, Rank: 26
# Top MIN Players Fantasy Points Last 5 (60% or fewer rosters)
# Ryan Hartman, RW (54.03% rostered): 16.1 fantasy points (3.22 FPPG)
# Marco Rossi, C (2.88% rostered): 11.2 fantasy points (2.24 FPPG)
# Jake Middleton, D (5.88% rostered): 10.1 fantasy points (2.02 FPPG)
#
# Goalies against NYR score: 0.2 FPAPG, Rank: 27
# Marc-Andre Fleury (15.53% rostered) last five: 2 appearances, FPPG: 0.2, FP: 0.4
# Filip Gustavsson (83.83% rostered) last five: 3 appearances, FPPG: -2.93, FP: -8.8
#
# -------------------------
#
# Calgary Flames at Seattle Kraken
# 10 p.m., Climate Pledge Arena
#
# Forwards against SEA score: 15.93 FPAPG, Rank: 17
# Defence against SEA score: 10.53 FPAPG, Rank: 5
# Top CGY Players Fantasy Points Last 5 (60% or fewer rosters)
#
# Goalies against SEA score: 3.96 FPAPG, Rank: 7
# Jacob Markstrom (58.4% rostered) last five: 4 appearances, FPPG: -1.35, FP: -5.4
# Dan Vladar (0.31% rostered) last five: 1 appearances, FPPG: -7.2, FP: -7.2
#
# Forwards against CGY score: 16.22 FPAPG, Rank: 15
# Defence against CGY score: 10.75 FPAPG, Rank: 2
# Top SEA Players Fantasy Points Last 5 (60% or fewer rosters)
# Jaden Schwartz, C (16.8% rostered): 13.7 fantasy points (2.74 FPPG)
# Oliver Bjorkstrand, RW (11.05% rostered): 9.6 fantasy points (1.92 FPPG)
# Justin Schultz, D (1.04% rostered): 9.3 fantasy points (1.86 FPPG)
# Will Borgen, D (0.43% rostered): 9.0 fantasy points (1.8 FPPG)
# Brian Dumoulin, D (4.13% rostered): 8.8 fantasy points (1.76 FPPG)
#
# Goalies against CGY score: 5.42 FPAPG, Rank: 2
# Philipp Grubauer (8.88% rostered) last five: 2 appearances, FPPG: 5.6, FP: 11.2
# Joey Daccord (1.47% rostered) last five: 3 appearances, FPPG: 1.6, FP: 4.8
#
# -------------------------
#
# Pittsburgh Penguins at San Jose Sharks
# 10 p.m., SAP Center at San Jose
#
# Forwards against SJS score: 20.22 FPAPG, Rank: 1
# Defence against SJS score: 10.67 FPAPG, Rank: 4
# Top PIT Players Fantasy Points Last 5 (60% or fewer rosters)
#
# Goalies against SJS score: 7.44 FPAPG, Rank: 1
# Tristan Jarry (78.01% rostered) last five: 4 appearances, FPPG: 0.1, FP: 0.4
# Magnus Hellberg (0.07% rostered) last five: 1 appearances, FPPG: -1.0, FP: -1.0
# Alex Nedeljkovic (0.79% rostered) last five: 1 appearances, FPPG: -2.0, FP: -2.0
#
# Forwards against PIT score: 17.96 FPAPG, Rank: 6
# Defence against PIT score: 8.42 FPAPG, Rank: 24
# Top SJS Players Fantasy Points Last 5 (60% or fewer rosters)
# Kyle Burroughs, D (0.2% rostered): 9.9 fantasy points (1.98 FPPG)
# Mario Ferraro, D (4.71% rostered): 9.1 fantasy points (1.82 FPPG)
# Fabian Zetterlund, LW (0.16% rostered): 9.0 fantasy points (1.8 FPPG)
#
# Goalies against PIT score: 3.73 FPAPG, Rank: 10
# Mackenzie Blackwood (2.32% rostered) last five: 4 appearances, FPPG: -1.6, FP: -6.4
# Kaapo Kahkonen (0.31% rostered) last five: 3 appearances, FPPG: -2.73, FP: -8.2
#
# -------------------------
#
# Dallas Stars at Vancouver Canucks
# 10 p.m., Rogers Arena
#
# Forwards against VAN score: 14.01 FPAPG, Rank: 25
# Defence against VAN score: 8.06 FPAPG, Rank: 27
# Top DAL Players Fantasy Points Last 5 (60% or fewer rosters)
# Matt Duchene, C (15.88% rostered): 11.4 fantasy points (2.28 FPPG)
# Esa Lindell, D (33.45% rostered): 11.3 fantasy points (2.26 FPPG)
# Thomas Harley, D (1.07% rostered): 10.0 fantasy points (2.0 FPPG)
# Evgenii Dadonov, RW (0.28% rostered): 8.8 fantasy points (1.76 FPPG)
#
# Goalies against VAN score: -2.5 FPAPG, Rank: 32
# Jake Oettinger (99.61% rostered) last five: 3 appearances, FPPG: 6.27, FP: 18.8
# Scott Wedgewood (0.76% rostered) last five: 2 appearances, FPPG: 2.6, FP: 5.2
#
# Forwards against DAL score: 14.0 FPAPG, Rank: 26
# Defence against DAL score: 9.14 FPAPG, Rank: 16
# Top VAN Players Fantasy Points Last 5 (60% or fewer rosters)
# Filip Hronek, D (59.44% rostered): 11.7 fantasy points (2.34 FPPG)
# Carson Soucy, D (0.3% rostered): 10.7 fantasy points (2.14 FPPG)
# Anthony Beauvillier, LW (1.53% rostered): 10.5 fantasy points (2.1 FPPG)
# Tyler Myers, D (4.61% rostered): 9.1 fantasy points (1.82 FPPG)
#
# Goalies against DAL score: 0.13 FPAPG, Rank: 28
# Thatcher Demko (87.07% rostered) last five: 4 appearances, FPPG: 7.0, FP: 28.0
# Casey DeSmith (2.43% rostered) last five: 1 appearances, FPPG: -3.0, FP: -3.0
#
# -------------------------
#
# Colorado Avalanche at Vegas Golden Knights
# 10 p.m., T-Mobile Arena
#
# Forwards against VGK score: 13.69 FPAPG, Rank: 27
# Defence against VGK score: 7.9 FPAPG, Rank: 30
# Top COL Players Fantasy Points Last 5 (60% or fewer rosters)
# Ryan Johansen, C (20.1% rostered): 11.2 fantasy points (2.24 FPPG)
#
# Goalies against VGK score: -0.93 FPAPG, Rank: 31
# Ivan Prosvetov (2.38% rostered) last five: 2 appearances, FPPG: 4.2, FP: 8.4
# Alexandar Georgiev (99.27% rostered) last five: 4 appearances, FPPG: -0.7, FP: -2.8
#
# Forwards against COL score: 12.99 FPAPG, Rank: 30
# Defence against COL score: 8.02 FPAPG, Rank: 29
# Top VGK Players Fantasy Points Last 5 (60% or fewer rosters)
# William Karlsson, C (39.69% rostered): 12.4 fantasy points (2.48 FPPG)
# Alec Martinez, D (33.36% rostered): 11.7 fantasy points (2.34 FPPG)
#
# Goalies against COL score: 1.78 FPAPG, Rank: 17
# Logan Thompson (74.3% rostered) last five: 3 appearances, FPPG: 5.47, FP: 16.4
# Adin Hill (87.38% rostered) last five: 2 appearances, FPPG: 2.2, FP: 4.4
#
# -------------------------
#
# SUNDAY
# New Jersey Devils at Chicago Blackhawks
# 7 p.m., United Center
#
# Forwards against CHI score: 17.9 FPAPG, Rank: 7
# Defence against CHI score: 9.7 FPAPG, Rank: 10
# Top NJD Players Fantasy Points Last 5 (60% or fewer rosters)
# Erik Haula, LW (15.58% rostered): 9.6 fantasy points (1.92 FPPG)
#
# Goalies against CHI score: 4.51 FPAPG, Rank: 4
# Vitek Vanecek (81.35% rostered) last five: 5 appearances, FPPG: 2.28, FP: 11.4
# Akira Schmid (5.15% rostered) last five: 1 appearances, FPPG: -5.0, FP: -5.0
#
# Forwards against NJD score: 17.32 FPAPG, Rank: 9
# Defence against NJD score: 10.96 FPAPG, Rank: 1
# Top CHI Players Fantasy Points Last 5 (60% or fewer rosters)
# Connor Murphy, D (2.55% rostered): 10.4 fantasy points (2.08 FPPG)
#
# Goalies against NJD score: -0.76 FPAPG, Rank: 30
# Petr Mrazek (9.19% rostered) last five: 4 appearances, FPPG: 0.75, FP: 3.0
# Arvid Soderblom (1.39% rostered) last five: 2 appearances, FPPG: -8.6, FP: -17.2
#
# -------------------------
#
# Vegas Golden Knights at Anaheim Ducks
# 8 p.m., Honda Center
#
# Forwards against ANA score: 15.58 FPAPG, Rank: 19
# Defence against ANA score: 9.16 FPAPG, Rank: 15
# Top VGK Players Fantasy Points Last 5 (60% or fewer rosters)
# William Karlsson, C (39.69% rostered): 12.4 fantasy points (2.48 FPPG)
# Alec Martinez, D (33.36% rostered): 11.7 fantasy points (2.34 FPPG)
#
# Goalies against ANA score: 0.66 FPAPG, Rank: 26
# Logan Thompson (74.3% rostered) last five: 3 appearances, FPPG: 5.47, FP: 16.4
# Adin Hill (87.38% rostered) last five: 2 appearances, FPPG: 2.2, FP: 4.4
#
# Forwards against VGK score: 13.69 FPAPG, Rank: 27
# Defence against VGK score: 7.9 FPAPG, Rank: 30
# Top ANA Players Fantasy Points Last 5 (60% or fewer rosters)
# Mason McTavish, C (50.83% rostered): 15.4 fantasy points (3.08 FPPG)
# Troy Terry, RW (56.68% rostered): 14.0 fantasy points (2.8 FPPG)
# Cam Fowler, D (44.17% rostered): 13.1 fantasy points (2.62 FPPG)
# Pavel Mintyukov, D (12.43% rostered): 12.3 fantasy points (2.46 FPPG)
# Radko Gudas, D (32.77% rostered): 11.6 fantasy points (2.32 FPPG)
#
# Goalies against VGK score: -0.93 FPAPG, Rank: 31
# Lukas Dostal (10.31% rostered) last five: 4 appearances, FPPG: 4.8, FP: 19.2
# John Gibson (10.06% rostered) last five: 2 appearances, FPPG: 1.3, FP: 2.6
#
# -------------------------

# %%
def convert_to_minutes_seconds(seconds):
    minutes = seconds // 60
    remaining_seconds = seconds % 60
    return f"{minutes}:{remaining_seconds:02d}"

convert_to_minutes_seconds(summary_stats.loc[summary_stats['name'] == "Barrett Hayton"]['timeOnIce'].values[0])
# Out:
# '195:05'
